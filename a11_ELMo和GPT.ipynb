# %% [markdown]
# # Transformer、ELMO和GPT
#
# Transformer、ELMO和GPT都是自然语言处理领域中的重要模型，它们在不同的任务和应用中发挥着关键作用。下面是它们之间的简要区别和联系：
#
# 1. Transformer（变形金刚）:
# Transformer是一种用于序列到序列（Sequence-to-Sequence）任务的神经网络模型，最初被广泛应用于机器翻译任务。它引入了自注意力机制（Self-Attention）来建立输入序列中单词之间的关联性。Transformer的核心思想是通过多层的自注意力和前馈神经网络层来进行序列建模。它的优势在于可以并行计算，因此在处理长序列时更高效。
#
# 2. ELMO（Embeddings from Language Models）:
# ELMO是一种基于上下文词向量（Contextual Word Embeddings）的表示学习模型。ELMO使用双向语言模型来生成每个单词的词向量，同时考虑上下文的语义信息。与传统的词向量模型（如Word2Vec和GloVe）不同，ELMO的词向量是根据整个句子的语境动态生成的。这使得ELMO能够更好地捕捉词汇的多义性和上下文相关性。
#
# 3. GPT（Generative Pre-trained Transformer）:
# GPT是一种基于Transformer架构的预训练语言模型。GPT采用了无监督的方式进行预训练，使用大规模的语料库来学习语言的统计特征。预训练完成后，GPT可以用于多种下游任务，如文本生成、问答系统和语义理解。GPT的一个关键特点是使用了自回归（autoregressive）的方式，即在生成输出时，依次生成每个单词，利用先前生成的单词来指导后续生成。
#
# 联系：
# - Transformer是GPT和ELMO的底层架构，两者都使用了Transformer模型。
# - ELMO和GPT都是预训练模型，利用大规模语料进行训练，然后在下游任务上进行微调。
# - GPT和ELMO都可以用于多个自然语言处理任务，如文本生成、文本分类和命名实体识别等。
#
# 区别：
# - ELMO是一种基于上下文的词向量模型，重点关注每个单词在不同上下文中的语义表示。而GPT是一个预训练语言模型，它生成下一个单词的概率分布。
# - GPT使用了自回归（autoregressive）的方式，即生成输出时依次生成每个单词，而ELMO并没有显式的生成过程。
# - GPT生成的是一段连续的文本，而EL
#
# MO生成的是每个单词的上下文向量。
# - GPT通常用于生成文本和问答任务，而ELMO更适用于文本分类和句子级别的任务。
#
# 综上所述，Transformer是底层架构，ELMO是基于上下文的词向量模型，而GPT是一种预训练语言模型，它们在某些方面有共同之处，但也有一些重要的区别。这些模型各自有不同的优势和适用场景，根据具体任务的需求来选择合适的模型。

# %% [markdown]
# ## ELMo

# %%
from torch import nn, optim
import torch
from torch.nn.functional import cross_entropy, softmax
import utils
from torch.utils.data import DataLoader
import os

# %%
class ELMo(nn.Module):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super(ELMo, self).__init__()
        self.n_layers = n_layers
        self.units = units
        self.v_dim = v_dim

        #encoder
        self.word_embed = nn.Embedding(num_embeddings=v_dim, embedding_dim=emb_dim, padding_idx=0)
        self.word_embed.weight.data.normal_(0, 0.1)

        #forward LSTM
        self.fs = nn.ModuleList([
            nn.LSTM(input_size=emb_dim, hidden_size=units, batch_first=True)
            if i == 0 else
            nn.LSTM(input_size=units, hidden_size=units, batch_first=True)
            for i in range(n_layers)
        ])
        self.f_logits = nn.Linear(in_features=units, out_features=v_dim)

        #backward LSTM
        self.bs = nn.ModuleList([
            nn.LSTM(input_size=emb_dim, hidden_size=units, batch_first=True)
            if i == 0 else
            nn.LSTM(input_size=units, hidden_size=units, batch_first=True)
            for i in range(n_layers)
        ])
        self.b_logits = nn.Linear(in_features=units, out_features=v_dim)

        self.opt = optim.Adam(self.parameters(), lr=lr)

    def forward(self,seqs):
        device = next(self.parameters()).device
        embedded = self.word_embed(seqs)    # [n, step, emb_dim]
        fxs = [embedded[:, :-1, :]]         # [n, step-1, emb_dim]
        bxs = [embedded[:, 1:, :]]          # [n, step-1, emb_dim]
        (h_f,c_f) = (torch.zeros(1,seqs.shape[0],self.units).to(device),torch.zeros(1,seqs.shape[0],self.units).to(device)) #初始化前向传播的隐藏状态(h_f,c_f)为全零张量，这里使用了LSTM模型，因此h_f和c_f的维度为[1, n, units]，其中n表示批量大小，units表示LSTM隐藏单元的数量。
        (h_b,c_b) = (torch.zeros(1,seqs.shape[0],self.units).to(device),torch.zeros(1,seqs.shape[0],self.units).to(device)) #初始化后向传播的隐藏状态(h_b, c_b)为全零张量
        #对于前向和后向的LSTM层对，使用zip函数遍历前向层列表self.fs和后向层列表self.bs
        for fl,bl in zip(self.fs,self.bs):
            # 对于当前前向LSTM层fl，将前一个步骤的输出fxs[-1]和前向隐藏状态(h_f, c_f)作为输入，执行前向传播操作。返回前向传播的输出张量output_f和更新后的前向隐藏状态(h_f, c_f)
            output_f,(h_f,c_f) = fl(fxs[-1], (h_f,c_f))   # [n, step-1, units], [1, n, units]
            fxs.append(output_f)
            # 对于当前后向LSTM层bl，将翻转的前一个步骤的输出torch.flip(bxs[-1],dims=[1,])和后向隐藏状态(h_b, c_b)作为输入，执行后向传播操作。返回后向传播的输出张量output_b和更新后的后向隐藏状态(h_b, c_b)
            output_b,(h_b,c_b) = bl(torch.flip(bxs[-1],dims=[1,]), (h_b,c_b)) # [n, step-1, units], [1, n, units]
            bxs.append(torch.flip(output_b,dims=(1,)))
        return fxs,bxs

    def step(self,seqs):
        self.opt.zero_grad()
        fo,bo = self(seqs)  #调用forward函数，返回前向LSTM层和后向LSTM层的输出
        # 全连接层
        fo = self.f_logits(fo[-1])  # [n, step-1, v_dim]
        bo = self.b_logits(bo[-1])  # [n, step-1, v_dim]
        # 损失函数
        loss = (
            cross_entropy(fo.reshape(-1,self.v_dim),seqs[:,1:].reshape(-1)) +
            cross_entropy(bo.reshape(-1,self.v_dim),seqs[:,:-1].reshape(-1)))/2
        loss.backward()
        self.opt.step()
        return loss.cpu().detach().numpy(), (fo,bo)

    def get_emb(self,seqs):
        fxs,bxs = self(seqs)    #调用forward函数，返回前向LSTM层和后向LSTM层的输出
        xs = [
            #创建一个列表xs，将前向传播和后向传播的第一层的输出进行拼接。使用torch.cat函数将前向传播的输出fxs[0][:,1:,:]和后向传播的输出bxs[0][:,:-1,:]在维度2上进行拼接。然后将拼接后的张量转移到CPU上，并使用.data.numpy()将其转换为NumPy数组
            torch.cat((fxs[0][:,1:,:],bxs[0][:,:-1,:]),dim=2).cpu().data.numpy()
        ] + [
            #对于后续的前向传播和后向传播的输出层，使用列表推导式遍历fxs[1:]和bxs[1:]，分别表示从第二层开始的前向传播和后向传播的输出。对每一层，使用torch.cat函数将前向传播的输出f[:,1:,:]和后向传播的输出b[:,:-1,:]在维度2上进行拼接。然后将拼接后的张量转移到CPU上，并使用.data.numpy()将其转换为NumPy数组
            torch.cat((f[:,1:,:],b[:,:-1,:]),dim=2).cpu().data.numpy() for f,b in zip(fxs[1:],bxs[1:])
        ]
        for x in xs:    #遍历列表xs中的每个嵌入表示，并打印其形状信息
            print("layers shape=",x.shape)
        return xs   #返回嵌入表示列表xs

# %%
def export_w2v(model,data,device):
    # 加载训练好的ELMo模型的参数。通过torch.load函数加载模型参数文件model.pth，并使用map_location参数将模型加载到指定的设备上（CPU或GPU）。加载后的模型参数会更新到model对象中
    model.load_state_dict(torch.load("./visual/models/elmo/model.pth",map_location=device))
    emb = model.get_emb(data)   #调用模型的get_emb函数，传入输入数据data，获取输入数据的嵌入表示。将嵌入表示赋值给变量emb
    print(emb)

# %%
def train():
    dataset = utils.MRPCSingle("./MRPC",rows=2000)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    print('num word: ',dataset.num_word)
    model = ELMo(v_dim = dataset.num_word,emb_dim = UNITS, units=UNITS, n_layers=N_LAYERS,lr=LEARNING_RATE)
    if torch.cuda.is_available():
        print("GPU train avaliable")
        device =torch.device("cuda")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        model = model.cpu()
    loader = DataLoader(dataset,batch_size=BATCH_SIZE,shuffle=True)
    for i in range(10):
        for batch_idx , batch in enumerate(loader):
            batch = batch.type(torch.LongTensor).to(device)
            loss, (fo,bo) = model.step(batch)
            if batch_idx % 20 ==0:
                fp = fo[0].cpu().data.numpy().argmax(axis=1)
                bp = bo[0].cpu().data.numpy().argmax(axis=1)
                print("\n\nEpoch: ", i,
                "| batch: ", batch_idx,
                "| loss: %.3f" % loss,
                "\n| tgt: ", " ".join([dataset.i2v[i] for i in batch[0].cpu().data.numpy() if i != dataset.pad_id]),
                "\n| f_prd: ", " ".join([dataset.i2v[i] for i in fp if i != dataset.pad_id]),
                "\n| b_prd: ", " ".join([dataset.i2v[i] for i in bp if i != dataset.pad_id]),
                )
    os.makedirs("./visual/models/elmo",exist_ok=True)
    # 使用torch.save函数将模型的状态字典（state_dict）保存为文件。状态字典包含了模型的所有参数和缓冲区，可以通过加载该文件来还原模型的状态。
    torch.save(model.state_dict(),"./visual/models/elmo/model.pth")
    # 调用export_w2v函数，传入模型对象model、数据batch[:4]和设备device。这行代码执行的是前面提到的导出模型词向量的过程
    export_w2v(model,batch[:4],device)

# %%
if __name__ == "__main__":
    train()
# Out:
# num word:  12880
# GPU train avaliable
#
#
# Epoch:  0 | batch:  0 | loss: 9.474
# | tgt:  <GO> the women then had follow-up examinations after five , <NUM> and <NUM> years . <SEP>
# | f_prd:  plain suem smaller seems smaller smaller smaller smaller smaller smaller smaller smaller smaller low-income smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller smaller
# | b_prd:  relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively relatively hostages hostages petitioned
#
#
# Epoch:  0 | batch:  20 | loss: 5.160
# | tgt:  <GO> the us government and private technology experts have warned that hackers plan to attack thousands of websites on sunday in a loosely co-ordinated <quote> contest <quote> that could disrupt internet traffic . <SEP>
# | f_prd:
# | b_prd:
#
#
# Epoch:  0 | batch:  40 | loss: 4.338
# | tgt:  <GO> it wants to force him to return his allegedly ill-gotten gains , with interest , and pay penalties . <SEP>
# | f_prd:  the the the the the the the the the the the ,
# | b_prd:
#
#
# Epoch:  0 | batch:  60 | loss: 4.693
# | tgt:  <GO> four harvey milk high school students who dressed as women were arrested yesterday for robbing men in the west village - and pretending to be police officers , sources said . <SEP>
# | f_prd:  the the the the the , , , , , , ,
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , , , , ,
#
#
# Epoch:  0 | batch:  80 | loss: 4.550
# | tgt:  <GO> amrozi accused his brother , whom he called <quote> the witness <quote> , of deliberately distorting his evidence . <SEP>
# | f_prd:  the the the the the , , , , , , , ,
# | b_prd:  the the the the the the , , , the the the the the the the the the . .
#
#
# Epoch:  0 | batch:  100 | loss: 4.009
# | tgt:  <GO> for example , the dow dropped more than <NUM> points , or <NUM> percent , from may to october <NUM> , largely because of terrorism fears driven by the headlines . <SEP>
# | f_prd:  the the the the , , , , , , , , , , , , ,
# | b_prd:  <GO> <GO> <GO> <GO> the the the the the the the the the the the the the the the the the the the the the the the the the the . .
#
#
# Epoch:  0 | batch:  120 | loss: 4.330
# | tgt:  <GO> while the shape of any military operation is unclear , jakarta has boosted the number of troops and police in the resource-rich province to more than <NUM> from <NUM> . <SEP>
# | f_prd:  the the the , , , , , , , , , , , , , . . . . . . <SEP> <SEP> <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the the the the the the the the the the the the the the the the the the the the the the the the the . .
#
#
# Epoch:  0 | batch:  140 | loss: 4.288
# | tgt:  <GO> community college students will see their tuition rise by $ <NUM> to $ <NUM> or <NUM> percent . <SEP>
# | f_prd:  the the the the , , , , , , , , , , <SEP> <SEP> <SEP>
# | b_prd:  <GO> <GO> the , , , , , , the , , the the the the the . .
#
#
# Epoch:  0 | batch:  160 | loss: 4.263
# | tgt:  <GO> after serving as a marine in world war ii , he began submitting articles to magazines . <SEP>
# | f_prd:  the the , , , , , , , , , , , . . . . <SEP>
# | b_prd:  <GO> <GO> the , , , , , , , , , , , , <NUM> . . <SEP>
#
#
# Epoch:  0 | batch:  180 | loss: 3.600
# | tgt:  <GO> brand-name drugs in canada tend to be cheaper than in the united states because of government price controls and a favorable exchange rate . <SEP>
# | f_prd:  the the , , , , the the , , , , , , , the , . . . . . . . <SEP>
# | b_prd:  <GO> <GO> the the , , the , , , , the , , , , , , , the the the , said . <SEP>
#
#
# Epoch:  0 | batch:  200 | loss: 4.465
# | tgt:  <GO> the long-running newsmagazine dateline nbc has been cut from three to two airings per week and is searching for a replacement for retiring co-anchor jane pauley . <SEP>
# | f_prd:  the the the the the , , the , , , , , , , , the , , , the , the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> , , , , , , , , , , , , , , , , , , , , , , <NUM> said . <SEP>
#
#
# Epoch:  0 | batch:  220 | loss: 4.389
# | tgt:  <GO> as many as <NUM> students at wheaton college will gather in the gym friday night for the first real dance in the christian school 's <NUM>-year history . <SEP>
# | f_prd:  the the the the the the the the the the , the the , , , the the the the , the the , . . . . <SEP>
# | b_prd:  <GO> <GO> the the , , the , , the , the the the the , the the the the , the the the , the <NUM> said . <SEP>
#
#
# Epoch:  0 | batch:  240 | loss: 3.458
# | tgt:  <GO> but stocks have roared higher in the past <NUM>- / <NUM> months amid hopes for an economic rebound . <SEP>
# | f_prd:  the the , the , the the the , , , , , the , the . . . <SEP>
# | b_prd:  <GO> <GO> the the , , , the , , , the , the , , , the said . <SEP>
#
#
# Epoch:  1 | batch:  0 | loss: 3.596
# | tgt:  <GO> she said he persisted and she eventually allowed him to fix her bike while she sat in the front seat of his car . <SEP>
# | f_prd:  the the , the , the the the , , the , the the the the . . the . . . . . <SEP>
# | b_prd:  <GO> <GO> the the , the the the , , the the , , the the , , the the , , <NUM> said . <SEP>
#
#
# Epoch:  1 | batch:  20 | loss: 3.697
# | tgt:  <GO> the new found planet is the only one known to orbit such a double-star system . <SEP>
# | f_prd:  the the the the , the the the the , the , the the . . <SEP>
# | b_prd:  <GO> the the the , , , , the , the , , , said said . <SEP>
#
#
# Epoch:  1 | batch:  40 | loss: 3.851
# | tgt:  <GO> dancing was the only physical activity associated with a lower risk of dementia . <SEP>
# | f_prd:  the , the the , the the the the the , . . . <SEP>
# | b_prd:  <GO> <GO> the , the , the , , , the , <NUM> said . <SEP>
#
#
# Epoch:  1 | batch:  60 | loss: 3.528
# | tgt:  <GO> shares of lendingtree rose $ <NUM> , or <NUM> percent , to $ <NUM> after hitting $ <NUM> earlier . <SEP>
# | f_prd:  the , the the <NUM> <NUM> <NUM> <NUM> <NUM> , , the the <NUM> <NUM> the the <SEP> . . <SEP>
# | b_prd:  <GO> <GO> the , , the , , , <NUM> , , , the , the , the the said . <SEP>
#
#
# Epoch:  1 | batch:  80 | loss: 4.138
# | tgt:  <GO> at the accident scene , the driver was <quote> covered in blood <quote> but helped to remove children , wood said . <SEP>
# | f_prd:  the the the , , the the , the the , the , the the the the , the the . . <SEP>
# | b_prd:  <GO> <GO> the the , , , , , the , the , the , , the the , the <NUM> said . <SEP>
#
#
# Epoch:  1 | batch:  100 | loss: 3.701
# | tgt:  <GO> the new contract extends the guarantee that his annual pay and bonus will be at least $ <NUM> million a year . <SEP>
# | f_prd:  the the was , , the , the the , , the , the , the , <NUM> <NUM> . . . <SEP>
# | b_prd:  <GO> the the , , the , , , the , , , the , to to to <NUM> to the said . <SEP>
#
#
# Epoch:  1 | batch:  120 | loss: 3.853
# | tgt:  <GO> wyle 's feature credits also include <quote> white oleander , <quote> <quote> enough <quote> and <quote> donnie darko . <quote> <SEP>
# | f_prd:  the , the the the the the the , , the the the , the the the . . <SEP> <SEP>
# | b_prd:  <GO> <GO> , , , , , the , , , , , the , , the <NUM> <NUM> . . <SEP>
#
#
# Epoch:  1 | batch:  140 | loss: 3.656
# | tgt:  <GO> spot gold was quoted at $ <NUM> / <NUM> an ounce at <NUM> gmt , having marched up to $ <NUM> -- a level not seen since february <NUM> . <SEP>
# | f_prd:  the , the the , the <NUM> <NUM> <NUM> , the , <NUM> , , <NUM> the , <NUM> the <NUM> <NUM> <NUM> the , , , the . . <SEP>
# | b_prd:  <GO> the , the , , , , , , the , or <NUM> <NUM> , , , , , the , , , , , <NUM> the the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  160 | loss: 3.483
# | tgt:  <GO> mr. brendsel is expected to remain with the freddie mac foundation . <SEP>
# | f_prd:  the said , the <NUM> the , the the , . . <SEP>
# | b_prd:  <GO> the , the <NUM> , , , to the said <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  180 | loss: 3.772
# | tgt:  <GO> hp 's shipments increased <NUM> percent year-over-year , compared to an increase of <NUM> percent for dell . <SEP>
# | f_prd:  the said the , , , , , the <NUM> <NUM> the , the , . . . <SEP>
# | b_prd:  <GO> <GO> , , $ <NUM> , <NUM> the , , the <NUM> $ <NUM> <NUM> the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  200 | loss: 3.438
# | tgt:  <GO> <quote> it was to fly a plane into the white house , <quote> mr. karas said . <SEP>
# | f_prd:  the the , the the , the , the the , , the the the . . <SEP>
# | b_prd:  <GO> <GO> , , the , , <NUM> , the the <NUM> , to the <NUM> <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  220 | loss: 3.631
# | tgt:  <GO> <quote> he said they were in distress , <quote> said kingsville police chief sam granato . <SEP>
# | f_prd:  the the , the , the the , the the the , , , . . <SEP>
# | b_prd:  <GO> <GO> it the <NUM> <NUM> the <NUM> , , the , , the the <NUM> . <SEP>
#
#
# Epoch:  1 | batch:  240 | loss: 3.427
# | tgt:  <GO> reuters reported braun ended june with $ <NUM> in the bank , according to her fec report , and the rev. al sharpton reported $ <NUM> in the bank . <SEP>
# | f_prd:  the was , the the <NUM> the <NUM> , the new , the , the the , , the the first , , , , <NUM> percent the . . <SEP>
# | b_prd:  <GO> <GO> the , the , to the , , the <NUM> the , , the the <NUM> , , the , , , to to , in the <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  0 | loss: 3.330
# | tgt:  <GO> devries did make one stop in town wednesday - registering as a sex offender at the soledad police department . <SEP>
# | f_prd:  the said the the , , the , , the , the new , , the new , . . <SEP>
# | b_prd:  <GO> <GO> the , , , , , <NUM> , , , the , , of the the the <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  20 | loss: 3.707
# | tgt:  <GO> goldman is trying to sell the shares to institutional investors at $ us13.15 each , said the traders , who received calls from the securities firm 's sales force . <SEP>
# | f_prd:  the said the <NUM> the , new , the , , the <NUM> , , <quote> the new , <quote> , the , the new of and year . . <SEP>
# | b_prd:  <GO> <GO> the , , , , , the , , to the , <NUM> , of the <NUM> , , , <NUM> , the , percent , in <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  40 | loss: 3.405
# | tgt:  <GO> mr eddington is to meet union leaders today and tomorrow . <SEP>
# | f_prd:  the said , the the the , , to the . <SEP>
# | b_prd:  <GO> <GO> he , the and , , percent the <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  60 | loss: 3.270
# | tgt:  <GO> gov. linda lingle and other dignitaries are scheduled to be at the base to watch the launch . <SEP>
# | f_prd:  the dow , , the be , the to the the the new , the the statement . <SEP>
# | b_prd:  <GO> he , , the , , , , to , , , , to in the said . <SEP>
#
#
# Epoch:  2 | batch:  80 | loss: 3.637
# | tgt:  <GO> the embraer jets are scheduled to be delivered by september <NUM> . <SEP>
# | f_prd:  the dow jones , the <NUM> the the , the <NUM> . <SEP>
# | b_prd:  <GO> the the , , , the , <NUM> to $ <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  100 | loss: 3.280
# | tgt:  <GO> the schaumburg , ill.-based company had scheduled its earnings report to be released on tuesday after the close of trading . <SEP>
# | f_prd:  the dow , the , , the to new , , the the , the , the new , the . <SEP>
# | b_prd:  <GO> the <NUM> the the , , , to the , to be , , , , the percent the <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  120 | loss: 3.706
# | tgt:  <GO> <quote> i have heard the people of new york say , ' enough is enough , ' <quote> pataki said . <quote> <SEP>
# | f_prd:  the the , the the first , the company , , <quote> the , the , <quote> the the . . <SEP> <SEP>
# | b_prd:  <GO> <GO> the , in <NUM> <NUM> the a , <NUM> , , , , percent , , the percent <NUM> . . <SEP>
#
#
# Epoch:  2 | batch:  140 | loss: 3.053
# | tgt:  <GO> it even struck a deal for distribution and advertising with popular p2p service grokster . <SEP>
# | f_prd:  the , the the new , the , the , the new said . . <SEP>
# | b_prd:  <GO> <quote> , in the , the , the , the , the the said . <SEP>
#
#
# Epoch:  2 | batch:  160 | loss: 3.298
# | tgt:  <GO> analysts ' consensus estimate from thomson first call was for a loss of $ <NUM> a share , excluding one-time items . <SEP>
# | f_prd:  the said the industrial <NUM> <NUM> first york , a the first , <NUM> <NUM> , share , <NUM> year . . <SEP>
# | b_prd:  <GO> <quote> , , , the a , , <NUM> , a <NUM> to to in a percent , , percent said . <SEP>
#
#
# Epoch:  2 | batch:  180 | loss: 3.763
# | tgt:  <GO> both blair and bush have faced accusations that they manipulated intelligence about weapons of mass destruction to make the case for military action . <SEP>
# | f_prd:  <quote> said , the , the was , the , <NUM> , the the the the , the the company of the . . <SEP>
# | b_prd:  <GO> <GO> it the , , the , , , the , , <NUM> , , , to of the percent the the said . <SEP>
#
#
# Epoch:  2 | batch:  200 | loss: 3.388
# | tgt:  <GO> the agency said it would consider as timely any tax returns or payments due from friday through aug. <NUM> if they are completed by aug. <NUM> . <SEP>
# | f_prd:  the company said the , the the the the first , to <NUM> , to the , the <NUM> million the , the and the <NUM> . <SEP>
# | b_prd:  <GO> the <quote> , , , , to of a , , was , , , <NUM> , to , , , , percent to in said . <SEP>
#
#
# Epoch:  2 | batch:  220 | loss: 3.595
# | tgt:  <GO> <quote> although some firms show bpo savings , vendors overstate their current offerings , <quote> mccarthy said in a statement . <SEP>
# | f_prd:  <quote> the the , , the be , <quote> the the company , , <quote> the , said the statement . <SEP>
# | b_prd:  <GO> <quote> <quote> the , , the <NUM> , , to the the <NUM> , , , <NUM> in a <NUM> . <SEP>
#
#
# Epoch:  2 | batch:  240 | loss: 3.278
# | tgt:  <GO> only in the past few weeks have officials settled on the <NUM> percent figure . <SEP>
# | f_prd:  the the the first 's was , the , the the <NUM> percent . . <SEP>
# | b_prd:  <GO> shares in the a a and , , , in $ <NUM> the said . <SEP>
#
#
# Epoch:  3 | batch:  0 | loss: 2.886
# | tgt:  <GO> the telephone survey had a margin of error of <NUM> percentage points . <SEP>
# | f_prd:  the technology-laced was , the <NUM> of the , the percent . . <SEP>
# | b_prd:  <GO> the the , of the <NUM> in <NUM> $ <NUM> <NUM> <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  20 | loss: 3.464
# | tgt:  <GO> physicians who violate the ban would be subject to fines and up to two years in prison . <SEP>
# | f_prd:  the <NUM> , the first 's the the to <NUM> to the to <NUM> year in the . <SEP>
# | b_prd:  <GO> <quote> , , the , to the , , <NUM> , , to <NUM> <NUM> in said . <SEP>
#
#
# Epoch:  3 | batch:  40 | loss: 3.561
# | tgt:  <GO> elena slough , considered to be the nation 's oldest person and the third oldest person in the world , died early sunday morning . <SEP>
# | f_prd:  the technology-laced , the the the the first of <NUM> time , the first york , , the first 's <quote> and said . . <SEP>
# | b_prd:  <GO> dow <NUM> , , to of the <NUM> a a <NUM> of the a a , of the <NUM> , to , the said . <SEP>
#
#
# Epoch:  3 | batch:  60 | loss: 3.169
# | tgt:  <GO> <quote> [ they ] were defined by dedication and courage , <quote> said the cia 's director george tenet . <SEP>
# | f_prd:  <quote> i the , , not to the , the to <quote> the the new , war of . . <SEP>
# | b_prd:  <GO> <GO> <quote> the , , , in , the <NUM> , , , the , and , the said . <SEP>
#
#
# Epoch:  3 | batch:  80 | loss: 3.204
# | tgt:  <GO> the current plan is to release the videotapes of the sessions , after u.s. review , on friday , said jim landale , a spokesman for the tribunal . <SEP>
# | f_prd:  the dow jones , the the , first of the first of <quote> the york , <quote> the , <quote> the first of <quote> first and the statement . <SEP>
# | b_prd:  <GO> the the , , to of the <NUM> of the <NUM> , of the <NUM> , , <NUM> , , , <NUM> , be , on the said . <SEP>
#
#
# Epoch:  3 | batch:  100 | loss: 3.008
# | tgt:  <GO> he praised the work of the rhodes trust , saying that it was a rhodes scholar at oxford who first interested him in politics . <SEP>
# | f_prd:  the said the first , the united states , <quote> the the , not first , and the the , , in to the . <SEP>
# | b_prd:  <GO> <GO> in the <NUM> in a a <NUM> , , , , of a be , the , a and to percent the said . <SEP>
#
#
# Epoch:  3 | batch:  120 | loss: 3.443
# | tgt:  <GO> rather , the us acted because the administration saw <quote> existing evidence in a new light , through the prism of our experience on september <NUM> <quote> . <SEP>
# | f_prd:  the of the first , the the first , the the , , the first york , <quote> the first , the first in the to . . <SEP>
# | b_prd:  <GO> <GO> <quote> the was , , the <NUM> , the be , , the the <NUM> , , the <NUM> to the , in $ he said . <SEP>
#
#
# Epoch:  3 | batch:  140 | loss: 3.187
# | tgt:  <GO> the horrific nature of the attacks is often fueled by a mix of tribal hatreds and a desire to spread terror in the region . <SEP>
# | f_prd:  the company 's , the first of the the in the first of the , , the first to the in in the statement . <SEP>
# | b_prd:  <GO> the the <NUM> in the , , was <NUM> in a <NUM> the <NUM> <NUM> in a according the the , in the said . <SEP>
#
#
# Epoch:  3 | batch:  160 | loss: 2.830
# | tgt:  <GO> sgt. ernest bucklew , <NUM> , was coming home from iraq to bury his mother in pennsylvania . <SEP>
# | f_prd:  the also also , <NUM> percent or the , , the , <NUM> the year of the . <SEP>
# | b_prd:  <GO> <GO> dow <NUM> $ <NUM> , to the <NUM> to , to in the , in <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  180 | loss: 2.970
# | tgt:  <GO> <quote> although some firms show bpo savings , vendors overstate their current offerings , <quote> john c. mccarthy , forrester group director , said . <SEP>
# | f_prd:  <quote> we the , , the have , <quote> said the way , , <quote> <quote> bush <quote> , <quote> said , , <quote> . <SEP>
# | b_prd:  <GO> <quote> of the , , the <NUM> , , to the the <NUM> , , and , <NUM> and the the percent he said . <SEP>
#
#
# Epoch:  3 | batch:  200 | loss: 3.760
# | tgt:  <GO> newcomer marissa jaret winokur in <quote> hairspray <quote> bested broadway veteran bernadette peters in <quote> gypsy <quote> for best actress in a musical . <SEP>
# | f_prd:  <quote> i not not , the the the <quote> have , , , , the <quote> the <quote> the , , the statement . <SEP>
# | b_prd:  <GO> <GO> coca-cola be , , , , , and 's and be , , and , , to be , in a said . <SEP>
#
#
# Epoch:  3 | batch:  220 | loss: 3.223
# | tgt:  <GO> in a separate complaint , the ftc alleged that aol and compuserve failed to deliver timely $ <NUM> rebates to consumers . <SEP>
# | f_prd:  the the statement , , the <NUM> , , the , the a to the the a <NUM> million to <NUM> . <SEP>
# | b_prd:  <GO> <GO> a the <NUM> , the was , on <NUM> , was <NUM> to to to to <NUM> , the <NUM> . <SEP>
#
#
# Epoch:  3 | batch:  240 | loss: 3.192
# | tgt:  <GO> in the united states , <NUM> percent of all women smoke . <SEP>
# | f_prd:  the <NUM> statement states , the percent , <NUM> <NUM> . . <SEP>
# | b_prd:  <GO> in the united <NUM> or <NUM> <NUM> to the to <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  0 | loss: 2.801
# | tgt:  <GO> based on having at least one of the symptoms , most students had been hung over between three and <NUM> times in the previous year . <SEP>
# | f_prd:  <quote> , the not <NUM> <NUM> years the first of the 's , not not in the the , the percent in the new york . <SEP>
# | b_prd:  <GO> <GO> , , to on <NUM> in a <NUM> and the it and was on <NUM> in <NUM> to united <NUM> of a a <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  20 | loss: 3.082
# | tgt:  <GO> the treasury said wants to give retail buyers of all treasury securities the ability eventually to manage holdings online in a single account . <SEP>
# | f_prd:  the company jones that to be the , , the the week , first to in be and , in the new . . <SEP>
# | b_prd:  <GO> the he he , to to on <NUM> to a the said the was , to to on , in a to said . <SEP>
#
#
# Epoch:  4 | batch:  40 | loss: 2.782
# | tgt:  <GO> still pending against rambus is a lawsuit brought by the federal trade commission . <SEP>
# | f_prd:  in was the the said the <NUM> in the the new states . . <SEP>
# | b_prd:  <GO> he <quote> said he of the percent <NUM> in the the the said . <SEP>
#
#
# Epoch:  4 | batch:  60 | loss: 2.567
# | tgt:  <GO> in september <NUM> , floods in the gard region killed <NUM> people . <SEP>
# | f_prd:  in <NUM> <NUM> , the the the united states of to percent . <SEP>
# | b_prd:  <GO> in in <NUM> was , , the the , to <NUM> <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  80 | loss: 3.614
# | tgt:  <GO> yehuda abraham , a <NUM>-year-old jeweler from new york 's diamond district , accepted a $ <NUM> down payment on behalf of lakhani for the first missile , investigators said . <SEP>
# | f_prd:  in the , the <NUM> court to the years , <NUM> was , was the <NUM> <NUM> million to and the , the , the united states of said said . <SEP>
# | b_prd:  <GO> dow <NUM> , a the <NUM> the new , the the <NUM> , to to to , <NUM> , on <NUM> in , of the the <NUM> , he said . <SEP>
#
#
# Epoch:  4 | batch:  100 | loss: 2.638
# | tgt:  <GO> dos reis is scheduled to be sentenced in danbury superior court this morning on charges of first-degree manslaughter and second-degree sexual assault . <SEP>
# | f_prd:  in state , a to be to to the years york , week , the , the the in the <NUM> york . <SEP>
# | b_prd:  <GO> wall it is , to , <NUM> in 's 's to the said the <NUM> in for , of of web said . <SEP>
#
#
# Epoch:  4 | batch:  120 | loss: 3.235
# | tgt:  <GO> he also accused royal courtiers of poisoning the brothers â â little minds â . <SEP>
# | f_prd:  he said said , 't , the the first 's the the murder . . <SEP>
# | b_prd:  <GO> he i and 's <NUM> to of the , and and and he said . <SEP>
#
#
# Epoch:  4 | batch:  140 | loss: 3.034
# | tgt:  <GO> only a big surge in consumer confidence has interrupted the bleak economic news . <SEP>
# | f_prd:  the the new york in the years , been the new quarter . . <SEP>
# | b_prd:  <GO> in a a , 's industrial it has of the and the said . <SEP>
#
#
# Epoch:  4 | batch:  160 | loss: 2.860
# | tgt:  <GO> the <NUM>-year bond us30yt = rr firmed <NUM> / <NUM> , taking its yield to <NUM> percent from <NUM> percent . <SEP>
# | f_prd:  the technology-laced jones industrial industrial rr > <NUM> points <NUM> , or <NUM> yield , <NUM> percent , <NUM> percent . <SEP>
# | b_prd:  <GO> the <NUM>-year < us30yt index index $ <NUM> $ <NUM> , for a , or <NUM> <NUM> up <NUM> <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  180 | loss: 2.948
# | tgt:  <GO> the broad standard & poors <NUM>-stock index was down <NUM> points to <NUM> . <SEP>
# | f_prd:  the technology-laced standard & poor average .dji was up <NUM> points , <NUM> . <SEP>
# | b_prd:  <GO> the broader jones industrial < <NUM> , , to <NUM> , $ <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  200 | loss: 2.808
# | tgt:  <GO> the bluetooth sig made its announcement at the bluetooth world congress in amsterdam this week . <SEP>
# | f_prd:  the new standard is the first in the <NUM> <NUM> 's in the in week . <SEP>
# | b_prd:  <GO> the we has in the , in the the on <NUM> in in last said . <SEP>
#
#
# Epoch:  4 | batch:  220 | loss: 2.527
# | tgt:  <GO> yesterday , shares closed up <NUM> cents , or <NUM> percent , at $ <NUM> . <SEP>
# | f_prd:  shares was <NUM> , down <NUM> percent , or <NUM> percent , to <NUM> <NUM> . <SEP>
# | b_prd:  <GO> shares the shares was or <NUM> points , or <NUM> percent , to $ <NUM> . <SEP>
#
#
# Epoch:  4 | batch:  240 | loss: 2.973
# | tgt:  <GO> <quote> we are going to continue to hammer away at the negotiations process until we reach an agreement , <quote> he said . <SEP>
# | f_prd:  <quote> we 'm not to be to be , , the company , , <quote> 's the statement , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> we to going to going to on , of the the , , to to the <NUM> , <quote> he said . <SEP>
#
#
# Epoch:  5 | batch:  0 | loss: 2.526
# | tgt:  <GO> then his body was dumped a few blocks away , found in a driveway on argyle road . <SEP>
# | f_prd:  in , attorneys was up $ profit states , , and with the new in the . . <SEP>
# | b_prd:  <GO> of the it was at a a on <NUM> was <NUM> in a <NUM> of the said . <SEP>
#
#
# Epoch:  5 | batch:  20 | loss: 2.635
# | tgt:  <GO> that would represent an increase of some <NUM> per cent from the year before , it added . <SEP>
# | f_prd:  in said be <NUM> <NUM> of <NUM> , percent cent , <NUM> <NUM> of the said said . <SEP>
# | b_prd:  <GO> it will was the <NUM> , about <NUM> per <NUM> in a <NUM> <NUM> , he <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  40 | loss: 2.702
# | tgt:  <GO> there are more surprises than you can possibly imagine , <quote> davis said after appearing with former u.s. president bill clinton at a school dedication . <SEP>
# | f_prd:  <quote> 's a , , a , be be , <quote> said said that the to the world executive , , , the statement . . <SEP>
# | b_prd:  <GO> he to is is that we to to <NUM> , said he , on , the of the the and , to an for said . <SEP>
#
#
# Epoch:  5 | batch:  60 | loss: 2.430
# | tgt:  <GO> <quote> this is a wide-ranging and continuing investigation which is likely to result in numerous other charges , <quote> mr spitzer said . <SEP>
# | f_prd:  <quote> we is not apologies , <quote> to with is not to be in the way , , <quote> said said said . <SEP>
# | b_prd:  <GO> <quote> there in a , a 's , it was going to , of and of <NUM> , , <quote> he said . <SEP>
#
#
# Epoch:  5 | batch:  80 | loss: 2.794
# | tgt:  <GO> in interviews with numerous engineers , most of whom have not spoken publicly until now , the lines of discord between nasa 's engineers and managers stand out in stark relief . <SEP>
# | f_prd:  in <NUM> , a statement , <quote> 's the <quote> been be support , <quote> , <quote> company of his and least , ex-girlfriend , other and to by the . . <SEP>
# | b_prd:  <GO> in , of the <NUM> , <NUM> <quote> we have is is <NUM> on <NUM> for the number of , of nation the , and not war said in of said . <SEP>
#
#
# Epoch:  5 | batch:  100 | loss: 2.820
# | tgt:  <GO> wal-mart said it would check all of its million-plus domestic workers to ensure they were legally employed . <SEP>
# | f_prd:  he has he would be a to least years role , , be more would not them . <SEP>
# | b_prd:  <GO> he said it to on <NUM> of the and and , to that he and be said . <SEP>
#
#
# Epoch:  5 | batch:  120 | loss: 2.728
# | tgt:  <GO> the nasdaq composite index , full of technology stocks , was lately up around <NUM> points . <SEP>
# | f_prd:  the technology-laced composite index was was , <NUM> was , was up to to <NUM> percent . <SEP>
# | b_prd:  <GO> the nasdaq composite <NUM> the <NUM> of & <NUM> , was , to to <NUM> <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  140 | loss: 2.591
# | tgt:  <GO> pg & e corp. shares were up <NUM> cents or <NUM> percent at $ <NUM> on the new york stock exchange on tuesday . <SEP>
# | f_prd:  shares shares e 's rose rose up <NUM> percent , <NUM> percent , <NUM> <NUM> in the new york stock exchange stock <NUM> . <SEP>
# | b_prd:  <GO> standard & nasdaq average <NUM> was rose <NUM> , rose <NUM> , to $ <NUM> on in new york stock <NUM> on <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  160 | loss: 2.778
# | tgt:  <GO> eighty-six u.n. workers who were wounded in tuesday 's bombing were airlifted out for medical care . <SEP>
# | f_prd:  he shares writer were was not in the and first in not in in comment . . <SEP>
# | b_prd:  <GO> the prime , who been <NUM> said secretary the it were on <quote> for the said . <SEP>
#
#
# Epoch:  5 | batch:  180 | loss: 2.479
# | tgt:  <GO> bob hope , master of the one-liner and americas favourite comedian , died with a smile on his face yesterday just months after celebrating his 100th birthday . <SEP>
# | f_prd:  in has , the 's the united , the , rehnquist , which , the united , a wife in in in in the the year . . <SEP>
# | b_prd:  <GO> the <NUM> the <NUM> of the , and 's 's <NUM> , , , to , of the , , <NUM> , to for a 's said . <SEP>
#
#
# Epoch:  5 | batch:  200 | loss: 2.638
# | tgt:  <GO> on wall street , trading resumed with some glitches from the blackout that continued to affect parts of new york city . <SEP>
# | f_prd:  in a year , <NUM> , and the of , the new , the in the the of the york stock . <SEP>
# | b_prd:  <GO> in al <NUM> , , , , a , , the , , , to of news the new the said . <SEP>
#
#
# Epoch:  5 | batch:  220 | loss: 2.750
# | tgt:  <GO> shares of san diego-based jack in the box closed at $ <NUM> , up <NUM> cents , or <NUM> percent , on the new york stock exchange . <SEP>
# | f_prd:  in of <NUM> quarter > and <NUM> <NUM> = down <NUM> <NUM> , or <NUM> percent , or <NUM> percent , to the nasdaq york stock exchange . <SEP>
# | b_prd:  <GO> shares in standard on <NUM> of 's index , at $ <NUM> was or <NUM> points , or <NUM> percent <NUM> on the new york stock <NUM> . <SEP>
#
#
# Epoch:  5 | batch:  240 | loss: 2.209
# | tgt:  <GO> the technology-laced nasdaq composite index .ixic was down <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the dow nasdaq composite index .ixic .ixic down <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite index index was down <NUM> points , or <NUM> percent , $ <NUM> . <SEP>
#
#
# Epoch:  6 | batch:  0 | loss: 2.458
# | tgt:  <GO> rumsfeld has been feuding for a long time with army leadership , and he passed over nine active-duty four-star generals . <SEP>
# | f_prd:  he , been 't to the state area , a , , and he said a a years people . . <SEP>
# | b_prd:  <GO> it has was , to the the , the william <NUM> , that and for to a for clarence said . <SEP>
#
#
# Epoch:  6 | batch:  20 | loss: 2.128
# | tgt:  <GO> boeing shares fell nearly <NUM> percent to $ <NUM> in afternoon new york stock exchange trade , while lockheed slipped <NUM> percent to $ <NUM> . <SEP>
# | f_prd:  shares shares fell <NUM> <NUM> percent , <NUM> <NUM> , the trading york stock exchange , , the the trading <NUM> percent in <NUM> <NUM> . <SEP>
# | b_prd:  <GO> wal-mart shares was rose <NUM> , to $ <NUM> in the new york the <NUM> <NUM> , , index up <NUM> , to to <NUM> . <SEP>
#
#
# Epoch:  6 | batch:  40 | loss: 2.222
# | tgt:  <GO> an attempt last month in the senate to keep the fund open for another year fell flat . <SEP>
# | f_prd:  the new to year in the united 's be the first <NUM> with the york in . . <SEP>
# | b_prd:  <GO> the shares last <NUM> of the expected to of an and <NUM> period a <NUM> april <NUM> . <SEP>
#
#
# Epoch:  6 | batch:  60 | loss: 2.742
# | tgt:  <GO> southwest exercised nine <NUM> options and six <NUM> options , which were accelerated for delivery next year . <SEP>
# | f_prd:  shares will those years percent , <NUM> than people and and was expected to the in year . <SEP>
# | b_prd:  <GO> it in least <NUM> , and in <NUM> <NUM> , , be <NUM> the the last said . <SEP>
#
#
# Epoch:  6 | batch:  80 | loss: 2.478
# | tgt:  <GO> more than half of the songs were purchased as albums , apple said . <SEP>
# | f_prd:  it than <NUM> , the new , been in the and said said . <SEP>
# | b_prd:  <GO> more a <NUM> on the he been , for <NUM> , he said . <SEP>
#
#
# Epoch:  6 | batch:  100 | loss: 2.380
# | tgt:  <GO> at <NUM> a.m. edt , fabian 's center was near latitude <NUM> north and longitude <NUM> west , or about <NUM> miles east of the leewards . <SEP>
# | f_prd:  in <NUM> , , , <NUM> 's cac-40 , up <NUM> <NUM> million , <NUM> <NUM> million , according <NUM> <NUM> percent in of the year . <SEP>
# | b_prd:  <GO> $ <NUM> . <NUM> , jones the <NUM> was on latitude <NUM> <NUM> , $ <NUM> <NUM> , , about <NUM> the percent of the said . <SEP>
#
#
# Epoch:  6 | batch:  120 | loss: 2.437
# | tgt:  <GO> <quote> united is continuing to deliver major cost reductions and is now coupling that effort with significant unit revenue improvement , <quote> chief financial officer jake brace said in a statement . <SEP>
# | f_prd:  <quote> we 's not to be our threats , and he not , that he to our terrorist , , , <quote> said executive president , the said the the statement . <SEP>
# | b_prd:  <GO> <quote> it is plans to a their be , it is is said a , to 's osama main year , the chief u.s. president john he said in a said . <SEP>
#
#
# Epoch:  6 | batch:  140 | loss: 2.656
# | tgt:  <GO> the commission has publicly said one of its goals is to ensure other producers ' server software can connect to desktop computers running windows as easily as microsoft 's can . <SEP>
# | f_prd:  the company has also filed it 's his suu , to be that hussein 's is it of have to be security , not , a as a 's environment . <SEP>
# | b_prd:  <GO> the he that he is part of 's it need to and and dr. security that it a according to his have and don and <quote> <quote> he he said . <SEP>
#
#
# Epoch:  6 | batch:  160 | loss: 2.530
# | tgt:  <GO> even the pizza delivery took part , unwittingly delivering a leaflet with the missing girl 's picture during his run to cruz 's house . <SEP>
# | f_prd:  a the first 's of a of the the the 1,700-square-mile with the united government , bathtub to the first in be and appointment . <SEP>
# | b_prd:  <GO> <quote> the 's , was <NUM> , , had a , of the the nation the , to to according and nation the said . <SEP>
#
#
# Epoch:  6 | batch:  180 | loss: 2.259
# | tgt:  <GO> starting on saturday , every computer infected with msblast is expected to start flooding microsoft 's windows update service with legitimate-looking connection requests . <SEP>
# | f_prd:  he in a , he husband officials to be and not to be to they 's internal , , to a democracy and . <SEP>
# | b_prd:  <GO> <GO> on <NUM> , a been , of it is expected to said of nation and an for , to to for said . <SEP>
#
#
# Epoch:  6 | batch:  200 | loss: 2.523
# | tgt:  <GO> police advised residents friday not to travel alone to convenience stores and to be watchful . <SEP>
# | f_prd:  she also his he for not be and , be more and he be . . <SEP>
# | b_prd:  <GO> also said said is is to <NUM> expected a the <NUM> expected to were said . <SEP>
#
#
# Epoch:  6 | batch:  220 | loss: 2.778
# | tgt:  <GO> in early u.s. trade , the euro was down <NUM> percent at $ <NUM> < eur = > . <SEP>
# | f_prd:  in <NUM> trading year , the dow rose up <NUM> percent , $ <NUM> in share = > . <SEP>
# | b_prd:  <GO> in in ( <NUM> , the index , rose <NUM> , to $ <NUM> < nasdaq year <NUM> . <SEP>
#
#
# Epoch:  6 | batch:  240 | loss: 2.273
# | tgt:  <GO> thomas and tauzin say , as do many doctors , that the bush administration has the power to correct some of those flaws . <SEP>
# | f_prd:  he said no said that <quote> he that years , the the united 's had been first of be their of the . . <SEP>
# | b_prd:  <GO> <quote> <quote> not <NUM> , to , for <NUM> , , , <NUM> , of 's plans the on out of and said . <SEP>
#
#
# Epoch:  7 | batch:  0 | loss: 2.238
# | tgt:  <GO> also in mosul , rebel gunmen on friday assassinated a sunni muslim tribal leader who backed the coalition . <SEP>
# | f_prd:  in in the , the was said the , the profit name hospital hospital in backed the case . <SEP>
# | b_prd:  <GO> <GO> of <NUM> , rebel <NUM> on there on a a 's prime , who on the said . <SEP>
#
#
# Epoch:  7 | batch:  20 | loss: 2.039
# | tgt:  <GO> the broader standard & poor 's <NUM> index .spx eased <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the technology-laced standard & poor 's <NUM> index .spx was <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | b_prd:  <GO> the broader standard & poor 's <NUM> index .ixic down <NUM> points , or <NUM> percent , to <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  40 | loss: 2.266
# | tgt:  <GO> she said no company official had received <quote> an individual target letter at this time . <quote> <SEP>
# | f_prd:  he said he husband said said been <quote> <quote> lot person pension , <quote> year . <quote> <SEP>
# | b_prd:  <GO> he <quote> the the he has to to an an a comment in the said . <quote> <SEP>
#
#
# Epoch:  7 | batch:  60 | loss: 2.425
# | tgt:  <GO> both bidders agreed to assume about $ <NUM> million in debt owed on the planes . <SEP>
# | f_prd:  in shares will to be to <NUM> <NUM> million , the or on the new . <SEP>
# | b_prd:  <GO> the has expected to was to $ <NUM> <NUM> in as <NUM> on the <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  80 | loss: 2.535
# | tgt:  <GO> sars , the deadly respiratory disease first detected in china last november , gave the agency its first real test of a new state-of-the-art emergency operations center . <SEP>
# | f_prd:  a of the <NUM>-year-old york court , office in the , week on the the ability that company round physician , the portable york marking services . . <SEP>
# | b_prd:  <GO> however , the â 's 's not <NUM> in <NUM> in <NUM> , that the of the a the end with the new with 's the said . <SEP>
#
#
# Epoch:  7 | batch:  100 | loss: 2.553
# | tgt:  <GO> pdc will also almost certainly fan the flames of speculation about longhorn 's release . <SEP>
# | f_prd:  he was also his his <quote> the first of homeland the the 's death . <SEP>
# | b_prd:  <GO> he was is almost have on the number to said in mother the said . <SEP>
#
#
# Epoch:  7 | batch:  120 | loss: 2.194
# | tgt:  <GO> the company posted a net loss of $ <NUM> million , or <NUM> cents per share , in the year-earlier period , it said in a statement wednesday . <SEP>
# | f_prd:  the company will a <NUM> <NUM> of <NUM> <NUM> million , or <NUM> percent , share , or the first products of the said in the <NUM> . . <SEP>
# | b_prd:  <GO> the it posted a a profit of $ <NUM> <NUM> , or <NUM> <NUM> per percent <NUM> in the the <NUM> , , <NUM> in a on said . <SEP>
#
#
# Epoch:  7 | batch:  140 | loss: 1.959
# | tgt:  <GO> in early u.s. trade , the euro was down <NUM> percent at $ <NUM> < eur = > . <SEP>
# | f_prd:  in <NUM> trading trading , the dow rose up <NUM> percent in $ <NUM> in year = > . <SEP>
# | b_prd:  <GO> in in the <NUM> , the index was rose <NUM> percent to $ <NUM> < eur year <NUM> . <SEP>
#
#
# Epoch:  7 | batch:  160 | loss: 1.972
# | tgt:  <GO> but in the first <NUM> seconds of the bout , family members knew it was an uneven match , jodie meyers , stacy young 's sister , said . <SEP>
# | f_prd:  in the the first <NUM> years , the dollar , said 's has the is a compromise government , franklin noteworthy , said c. , largest , r-colo . <SEP>
# | b_prd:  <GO> <GO> in the the <NUM> some of the <NUM> 's and , said , with an the . , , <NUM> , with sheriff the carolina he said . <SEP>
#
#
# Epoch:  7 | batch:  180 | loss: 2.098
# | tgt:  <GO> in a statement , the company said both bids would allow vivendi to <quote> maintain a substantial minority interest in a u.s. media corporation with excellent growth potential . <quote> <SEP>
# | f_prd:  the the statement , the <NUM>-year-old said that was , be support , a harry to 11th party , in the coma group , to his sites . . <quote> <SEP>
# | b_prd:  <GO> in a <NUM> , the he that that it would of it a to , a an or said and a 's our , of 's , sin . <quote> <SEP>
#
#
# Epoch:  7 | batch:  200 | loss: 2.515
# | tgt:  <GO> in a statement distributed friday , <NUM> chechen non-governmental organizations said they would boycott the vote . <SEP>
# | f_prd:  in a statement , die , a , have have and it would be the bit . <SEP>
# | b_prd:  <GO> in a were on <NUM> about <NUM> dr. tom he that and to to to said . <SEP>
#
#
# Epoch:  7 | batch:  220 | loss: 2.164
# | tgt:  <GO> <quote> it indicates we are starting the epidemic with more cases than last year , <quote> gerberding said . <SEP>
# | f_prd:  <quote> we is that are not the lot of a than , a year , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> he that we would on the charged with a more period this <NUM> , <quote> he said . <SEP>
#
#
# Epoch:  7 | batch:  240 | loss: 2.619
# | tgt:  <GO> a year or two later , <NUM> , or <NUM> per cent , of the youths reported that they had started to smoke , or had taken just a few puffs . <SEP>
# | f_prd:  a <NUM> ago <NUM> people in <NUM> percent a <NUM> percent cent , while the <NUM> that that it would been a be , a <NUM> a a the year weeks . <SEP>
# | b_prd:  <GO> last <NUM> of <NUM> <NUM> $ <NUM> , or <NUM> per <NUM> one of the who , , who , , to <NUM> , , , , to a a said . <SEP>
#
#
# Epoch:  8 | batch:  0 | loss: 2.157
# | tgt:  <GO> the hearing occurred a day after the pentagon for the first time singled out an officer , dallager , for not addressing the scandal . <SEP>
# | f_prd:  the two of the <NUM>-year-old after the first and the first time , by a <NUM>-year-old , dallager , and the cancer the spotlight . <SEP>
# | b_prd:  <GO> the shares <NUM> a , on the , of the the , not and 's <NUM> , <NUM> , , to on the said . <SEP>
#
#
# Epoch:  8 | batch:  20 | loss: 2.218
# | tgt:  <GO> but six months ago , the two sides managed to strike a $ 6.8-billion debt rollover deal , which expires in august . <SEP>
# | f_prd:  but far than ago , the company states cavalry to be a $ <NUM> share or year in according said in the . <SEP>
# | b_prd:  <GO> <GO> five <NUM> <NUM> , the <NUM> who expected to of to <NUM> 's with a <NUM> , , <NUM> in <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  40 | loss: 2.039
# | tgt:  <GO> treasurys long-range plan is to provide retail buyers of all treasury securities the ability to manage their holdings online in a single account . <SEP>
# | f_prd:  u.s. decision plan , to be their pharmacies of the the a the first to the in first in in the statement statement . <SEP>
# | b_prd:  <GO> emeryville-based the it trying to to on one of the to on the trying to with with holdings said in a single said . <SEP>
#
#
# Epoch:  8 | batch:  60 | loss: 2.118
# | tgt:  <GO> a $ <NUM> million natural-gas-fired power plant , for example , could replace up to $ <NUM> million in boilers yearly without adding new smog controls . <SEP>
# | f_prd:  a $ <NUM> million people troops maker , <NUM> example , and be a to $ <NUM> million in the adolph in the in year controls . <SEP>
# | b_prd:  <GO> a $ <NUM> new major the <NUM> , for <NUM> , will face up of $ <NUM> years in less more without epa new suu said . <SEP>
#
#
# Epoch:  8 | batch:  80 | loss: 2.141
# | tgt:  <GO> platinum prices soared to <NUM>-year highs earlier this year after president bush ( news - web sites ) proposed investing $ <NUM> billion for research on fuel cell-powered vehicles . <SEP>
# | f_prd:  shares <NUM> jam to <NUM> york from in year , <NUM> and had <NUM> - people sites ) ) investing $ <NUM> million in $ and tuesday cell-powered vehicles . <SEP>
# | b_prd:  <GO> platinum dollar expected a mount <NUM> earlier last year of george . - news - 3rd sites the same of $ <NUM> year of <NUM> on j.d. of <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  100 | loss: 1.961
# | tgt:  <GO> early wednesday , the benchmark <NUM>-year us10yt = rr had lost <NUM> / <NUM> in price , driving its yield up to <NUM> percent from <NUM> percent late tuesday . <SEP>
# | f_prd:  in thursday , the dollar <NUM>-year = = rr slid up <NUM> / <NUM> / <NUM> , <NUM> its yield to <NUM> <NUM> percent , <NUM> percent on thursday . <SEP>
# | b_prd:  <GO> on <NUM> , the the note us30yt = rr rr / <NUM> / <NUM> of <NUM> , taking its , yield up <NUM> yield down <NUM> <NUM> on said . <SEP>
#
#
# Epoch:  8 | batch:  120 | loss: 2.242
# | tgt:  <GO> scientists have reported a <NUM> percent decline in large predatory fish in the world 's oceans since a half century ago . <SEP>
# | f_prd:  shares reported a the profit percent lower in prison predatory fish in the first 's wealthiest since the year earlier in . <SEP>
# | b_prd:  <GO> stocks has of a <NUM> 's <NUM> in the tainted <NUM> in the company 's compared for a a year <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  140 | loss: 1.913
# | tgt:  <GO> the securities and exchange commission also filed a civil fraud complaint against dinh , of phoenixville . <SEP>
# | f_prd:  the company and exchange commission said filed a two-day area suit in the , said <NUM> . <SEP>
# | b_prd:  <GO> the securities 's exchange has , had an 's post cleared on percent percent in said . <SEP>
#
#
# Epoch:  8 | batch:  160 | loss: 2.123
# | tgt:  <GO> it would be cumbersome for restaurants that serve different meals each day , she said . <SEP>
# | f_prd:  he was be distributed for charges and ears his styles them workers and and said . <SEP>
# | b_prd:  <GO> it will for representative of restaurants the than an than the <NUM> , he said . <SEP>
#
#
# Epoch:  8 | batch:  180 | loss: 2.018
# | tgt:  <GO> adrian lamo , <NUM> , had told reporters he planned to surrender to the fbi in sacramento friday , but he then had second thoughts . <SEP>
# | f_prd:  myanmar , , who , was been his and was to be to the world , iraq in and and he was to a status . <SEP>
# | b_prd:  <GO> terri quattrone , <NUM> , , of said , , to , of the <NUM> in on <NUM> , , , and 's to said . <SEP>
#
#
# Epoch:  8 | batch:  200 | loss: 2.569
# | tgt:  <GO> after he was led into the execution chamber and strapped to a gurney , swisher raised his head and appeared to smile as the prison chaplain spoke in his ear . <SEP>
# | f_prd:  he he was taken that the first chamber of strapped to the growing , hedges and a conclusions of has to be on a u.s. , was in her statement . <SEP>
# | b_prd:  <GO> <quote> , who seen of the al crying and linked is a <NUM> , , of and , and going a <quote> , the and who <quote> of associated said . <SEP>
#
#
# Epoch:  8 | batch:  220 | loss: 2.037
# | tgt:  <GO> first , it 's found in most versions of windows , including the new windows server <NUM> . <SEP>
# | f_prd:  physicians college <NUM> 's sales about <NUM> 's of the , the the <NUM> york association <NUM> . <SEP>
# | b_prd:  <GO> however said company was <NUM> the expand percent for <NUM> , for the the <NUM> to <NUM> . <SEP>
#
#
# Epoch:  8 | batch:  240 | loss: 2.051
# | tgt:  <GO> the securities and exchange commission yesterday said companies trading on the biggest u.s. markets must win shareholder approval before granting stock options and other stock-based compensation plans to corporate executives . <SEP>
# | f_prd:  the two and exchange commission said said it in on the new province companies that be on than in a a street and a operations officials officials to be <NUM> . <SEP>
# | b_prd:  <GO> the securities senate the , <quote> of spotty said said the three 's have to with u.n. <quote> <quote> york an patent of other their and refused to for said . <SEP>
#
#
# Epoch:  9 | batch:  0 | loss: 1.880
# | tgt:  <GO> the dow jones industrial average finished the day down <NUM> points at <NUM> . <SEP>
# | f_prd:  the dow jones industrial average was <NUM> day after <NUM> percent , <NUM> . <SEP>
# | b_prd:  <GO> the dow jones industrial <NUM> taking a was down <NUM> , at <NUM> . <SEP>
#
#
# Epoch:  9 | batch:  20 | loss: 2.161
# | tgt:  <GO> john clare , dixons chief executive , objected to the commission 's findings . <SEP>
# | f_prd:  however anderson , dixons attorney executive , the to the united 's exchange . <SEP>
# | b_prd:  <GO> john however , and chief <NUM> , according , the mother for said . <SEP>
#
#
# Epoch:  9 | batch:  40 | loss: 1.799
# | tgt:  <GO> united issued a statement saying it will <quote> work professionally and cooperatively with all its unions . <quote> <SEP>
# | f_prd:  however 's a <quote> <quote> that would be be with and <quote> with <quote> <quote> <quote> . <quote> <SEP>
# | b_prd:  <GO> <GO> in a , said it self-healing to bill bound and <quote> to on the said . <quote> <SEP>
#
#
# Epoch:  9 | batch:  60 | loss: 1.678
# | tgt:  <GO> nevada is where the most women smoke , <NUM> percent . <SEP>
# | f_prd:  broomhead is a the <NUM> kernel were , <NUM> percent . <SEP>
# | b_prd:  <GO> it , of the its to <NUM> to <NUM> <NUM> . <SEP>
#
#
# Epoch:  9 | batch:  80 | loss: 1.562
# | tgt:  <GO> <quote> we continue to work with the saudis on this , but they did not , as of the time of this tragic event , provide the additional security we requested . <quote> <SEP>
# | f_prd:  <quote> we have to be for the world , his week <quote> he can not prevail <quote> the the united , the , event , <quote> the united world association said . <SEP> <SEP>
# | b_prd:  <GO> <quote> will plans to , of a , from said , that who is <NUM> , presence of the one <quote> the the part to that and that that have said . <quote> <SEP>
#
#
# Epoch:  9 | batch:  100 | loss: 2.066
# | tgt:  <GO> chiron already has nearly <NUM> percent acceptances from powderject 's shareholders . <SEP>
# | f_prd:  columbia has has sales <NUM> percent of in $ 's shareholders . <SEP>
# | b_prd:  <GO> chiron shares from from <NUM> , <NUM> on exchange exchange <NUM> . <SEP>
#
#
# Epoch:  9 | batch:  120 | loss: 1.823
# | tgt:  <GO> there are now <NUM> active probable cases in the gta , compared with <NUM> cases on june <NUM> . <SEP>
# | f_prd:  it is <NUM> <NUM> percent cent cases , <NUM> same , according with <NUM> percent in the <NUM> . <SEP>
# | b_prd:  <GO> it at least the with <NUM> <NUM> in the <NUM> , , and <NUM> <NUM> on to <NUM> . <SEP>
#
#
# Epoch:  9 | batch:  140 | loss: 1.916
# | tgt:  <GO> president bush flies to uganda friday hoping to polish his anti- aids credentials in a country hailed as an african pioneer in fighting the epidemic . <SEP>
# | f_prd:  police bush have to alter on as to be his efforst property to in the coma 's on the former pioneer in the the journalists . <SEP>
# | b_prd:  <GO> mr. also threat from on , trying to see his urge be work , a who <quote> as an a operations in in the said . <SEP>
#
#
# Epoch:  9 | batch:  160 | loss: 1.925
# | tgt:  <GO> just five months ago , dean committed to accepting taxpayer money and vowed to attack any democrat who didnt . <SEP>
# | f_prd:  also <NUM> months ago , an 's to be taxpayer money and have to be as rights , didnt . <SEP>
# | b_prd:  <GO> within five years <NUM> , been plans to to for bound and plans to and a those it monday . <SEP> <SEP>
#
#
# Epoch:  9 | batch:  180 | loss: 2.078
# | tgt:  <GO> he planned monday to formally announce the effort alongside several union presidents . <SEP>
# | f_prd:  he was to to be announce the budget of the years presidents . <SEP>
# | b_prd:  <GO> he on is to to to the cincinnati alongside a the monday . <SEP>
#
#
# Epoch:  9 | batch:  200 | loss: 2.108
# | tgt:  <GO> the national transportation safety board had subpoenaed him , but he initially ignored the order . <SEP>
# | f_prd:  the decision standard and chief administration subpoenaed suu , but said was no the bill . <SEP>
# | b_prd:  <GO> the the state the who had to <NUM> , <quote> he recently and the monday . <SEP>
#
#
# Epoch:  9 | batch:  220 | loss: 1.890
# | tgt:  <GO> they are due to appear in the brisbane magistrates court today . <SEP>
# | f_prd:  he also no to comment in the united prison court in . <SEP>
# | b_prd:  <GO> he was going will field in in brisbane the said comment . <SEP>
#
#
# Epoch:  9 | batch:  240 | loss: 2.018
# | tgt:  <GO> black democratic leaders were trying to arrange a meeting with democratic national committee chairman terry mcauliffe to discuss the layoffs of <NUM> minority staffers at party headquarters . <SEP>
# | f_prd:  officials players york , in to determine the generous in iraq rights chains because in mcauliffe to fellow the first of <NUM> to on at his publications . <SEP>
# | b_prd:  <GO> the apec troops be trying to in a , by and chief whose president terry is to among the city the the for rules baath the <NUM> . <SEP>
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[ 0.01265792, -0.07622013, -0.13092963, ..., -0.24118958,
#           0.39791366,  0.00577644],
#         [-0.31729397,  0.03147067, -0.4088311 , ...,  0.16681461,
#          -0.31859428, -0.05058149],
#         [ 0.03177487,  0.01548747, -0.3478015 , ..., -0.2322228 ,
#          -0.04630098,  0.33865416],
#         ...,
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479]],
#
#        [[ 0.02516588,  0.06055183,  0.09479523, ..., -0.00734723,
#          -0.26607165, -0.27304438],
#         [ 0.00124899, -0.2567935 , -0.15937988, ..., -0.09621987,
#           0.12369231,  0.16390814],
#         [-0.05958841,  0.40921968, -0.03773488, ...,  0.0674725 ,
#           0.08438174, -0.26830363],
#         ...,
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479]],
#
#        [[ 0.03499558, -0.24916546, -0.04894686, ...,  0.04152272,
#           0.02833675, -0.5812648 ],
#         [-0.02374163,  0.0963503 , -0.1841258 , ...,  0.05245394,
#           0.00768989, -0.15508762],
#         [ 0.10137232,  0.49160686, -0.09777509, ..., -0.19977796,
#          -0.00783495, -0.26898232],
#         ...,
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479]],
#
#        [[ 0.06381437, -0.16021922, -0.11422574, ...,  0.11372613,
#          -0.28578243,  0.03980127],
#         [ 0.12029982, -0.10508561, -0.13077728, ...,  0.15618144,
#           0.08048876,  0.0512649 ],
#         [-0.09768473, -0.1163548 , -0.11243442, ...,  0.12586004,
#           0.01615921,  0.11344201],
#         ...,
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479],
#         [-0.02916246, -0.10490133,  0.0295565 , ..., -0.2128311 ,
#          -0.08460644,  0.06070479]]], dtype=float32), array([[[ 1.16591007e-02, -3.58462989e-01,  5.45351684e-01, ...,
#           5.32071829e-01, -3.52855146e-01,  2.72216499e-01],
#         [ 7.36596763e-01,  5.09169698e-01, -3.28032345e-01, ...,
#           8.42492655e-03, -1.66138390e-03,  1.86434668e-02],
#         [ 7.13657975e-01,  1.03053509e-03, -1.49451866e-04, ...,
#           1.54561549e-01,  6.78610265e-01,  9.32898760e-01],
#         ...,
#         [ 5.16591668e-01,  3.81453981e-04, -2.54430430e-04, ...,
#          -1.14743384e-02, -1.02399569e-03,  9.91413057e-01],
#         [ 5.16356170e-01,  3.85896739e-04, -2.70529912e-04, ...,
#          -2.28359904e-02, -3.13360151e-03,  9.54407871e-01],
#         [ 5.16425312e-01,  3.89859924e-04, -2.84803013e-04, ...,
#          -1.96569681e-01, -1.53603945e-02,  7.14466453e-01]],
#
#        [[-3.16429771e-02,  7.47141778e-01,  9.08816040e-01, ...,
#           2.28333417e-02, -2.26050761e-04,  5.86846098e-02],
#         [ 3.74215044e-04,  1.49131477e-01,  4.31198865e-01, ...,
#          -4.95628715e-01, -9.02780712e-01,  9.82822359e-01],
#         [-5.25495231e-01,  1.94831222e-01,  9.16253403e-02, ...,
#           3.44494805e-02, -6.01425648e-01,  1.59758572e-02],
#         ...,
#         [ 7.81134725e-01,  2.52225233e-04, -2.63683760e-04, ...,
#          -1.14743384e-02, -1.02399569e-03,  9.91413057e-01],
#         [ 7.81666577e-01,  2.56429077e-04, -2.74760445e-04, ...,
#          -2.28359904e-02, -3.13360151e-03,  9.54407871e-01],
#         [ 7.82457352e-01,  2.59974680e-04, -2.83999339e-04, ...,
#          -1.96569681e-01, -1.53603945e-02,  7.14466453e-01]],
#
#        [[ 7.78298855e-01,  7.37704694e-01,  9.31200206e-01, ...,
#           6.76155696e-06, -3.21270339e-02,  5.79233766e-02],
#         [ 1.82198018e-01,  8.24051917e-01,  5.40966809e-01, ...,
#           1.50110111e-01, -2.50554740e-01,  5.47424734e-01],
#         [ 7.01364338e-01,  9.49043751e-01, -3.72933626e-01, ...,
#           2.96658259e-02, -3.50018501e-01,  2.85908650e-03],
#         ...,
#         [ 8.78497958e-01,  1.84326389e-04, -9.23558546e-05, ...,
#          -1.14743384e-02, -1.02399569e-03,  9.91413057e-01],
#         [ 8.74501467e-01,  1.91083513e-04, -1.01579630e-04, ...,
#          -2.28359904e-02, -3.13360151e-03,  9.54407871e-01],
#         [ 8.74833941e-01,  1.93522035e-04, -1.11050416e-04, ...,
#          -1.96569681e-01, -1.53603945e-02,  7.14466453e-01]],
#
#        [[ 5.69764338e-02, -1.65353790e-02,  1.55559033e-01, ...,
#          -5.24655282e-01, -6.95211738e-02,  1.35857910e-01],
#         [ 1.56207737e-02, -8.08061287e-02,  1.18912257e-01, ...,
#          -5.52810907e-01, -2.28983045e-01,  1.54812429e-02],
#         [ 2.25477263e-01,  4.12606522e-02, -1.52167901e-01, ...,
#           2.85663843e-01, -9.09062982e-01,  3.07862647e-02],
#         ...,
#         [ 5.25272906e-01,  2.78882304e-04, -1.58884475e-04, ...,
#          -1.14743384e-02, -1.02399569e-03,  9.91413057e-01],
#         [ 4.66623932e-01,  3.02813365e-04, -1.59479750e-04, ...,
#          -2.28359904e-02, -3.13360151e-03,  9.54407871e-01],
#         [ 4.34198737e-01,  3.16650345e-04, -1.74616958e-04, ...,
#          -1.96569681e-01, -1.53603945e-02,  7.14466453e-01]]],
#       dtype=float32), array([[[-8.65925789e-01,  9.99957204e-01, -5.87347476e-03, ...,
#           9.52842161e-02, -3.76493344e-03,  6.58968985e-02],
#         [-8.18481326e-01,  9.06938255e-01, -4.62583192e-02, ...,
#           4.36268572e-04, -1.14623057e-04,  4.03010519e-03],
#         [-9.73292828e-01,  3.70283514e-01, -6.03223612e-07, ...,
#           8.84029031e-01, -1.25365570e-01,  9.46402550e-01],
#         ...,
#         [-9.99999642e-01, -3.37360805e-04, -2.39506154e-03, ...,
#           9.99303639e-01, -9.97196496e-01,  9.98869240e-01],
#         [-9.99999523e-01, -3.19593033e-04, -2.36824388e-03, ...,
#           9.95907009e-01, -9.96120751e-01,  9.99134064e-01],
#         [-9.99999523e-01, -3.11460375e-04, -2.37611262e-03, ...,
#           9.74582911e-01, -9.78995025e-01,  9.99614954e-01]],
#
#        [[ 3.66595872e-02,  9.46688831e-01, -3.83604437e-01, ...,
#           9.99203265e-01, -4.58517820e-02,  6.08748524e-03],
#         [-4.47506346e-02,  9.99979377e-01, -7.61304379e-01, ...,
#           9.96828556e-01, -4.33585078e-01,  1.05293235e-03],
#         [-7.71521568e-01, -6.36984587e-01, -3.41148317e-01, ...,
#           9.67379212e-01, -1.17455445e-01,  4.13733942e-04],
#         ...,
#         [-9.99999166e-01, -5.03975352e-05, -3.70658468e-03, ...,
#           9.98891413e-01, -9.95105267e-01,  9.98858213e-01],
#         [-9.99999046e-01, -4.84873017e-05, -3.52119911e-03, ...,
#           9.93294358e-01, -9.98121560e-01,  9.99111593e-01],
#         [-9.99998927e-01, -4.66577003e-05, -3.36049846e-03, ...,
#           9.57717955e-01, -9.99123037e-01,  9.99690711e-01]],
#
#        [[ 7.60776103e-01,  9.83810306e-01, -6.98289722e-02, ...,
#           2.53693340e-03, -2.39109868e-04,  4.60920483e-03],
#         [ 2.84886383e-03,  9.99441922e-01, -9.58592724e-03, ...,
#           9.99977231e-01, -8.52478981e-01,  3.68007749e-01],
#         [ 7.58646369e-01, -6.97982132e-01, -1.51008368e-02, ...,
#           5.15509280e-04, -2.26177886e-04,  2.86327619e-02],
#         ...,
#         [-1.00000000e+00, -1.65589619e-04, -3.85539792e-03, ...,
#           9.98821020e-01, -9.96873438e-01,  9.97964025e-01],
#         [-9.99999881e-01, -1.74628614e-04, -4.27300576e-03, ...,
#           9.92932856e-01, -9.97830033e-01,  9.98415709e-01],
#         [-9.99999881e-01, -1.69599443e-04, -4.65773325e-03, ...,
#           9.55682337e-01, -9.93540227e-01,  9.99162674e-01]],
#
#        [[ 6.68806553e-01,  9.99363959e-01, -8.54555611e-03, ...,
#           9.81455266e-01, -9.62098222e-03,  1.53772160e-03],
#         [-3.46143901e-01,  9.99954820e-01, -1.90003198e-02, ...,
#           9.96156275e-01, -5.25052369e-01,  3.82811964e-01],
#         [-6.09631240e-01, -5.69324672e-01, -3.56902415e-03, ...,
#           2.73139685e-01, -9.62205410e-01,  6.11538529e-01],
#         ...,
#         [-9.98850346e-01, -1.23551305e-04, -1.34902028e-02, ...,
#           9.97697234e-01, -9.93612468e-01,  9.98444021e-01],
#         [-9.99843419e-01, -1.57976829e-04, -1.69962998e-02, ...,
#           9.85931277e-01, -9.98535573e-01,  9.99016523e-01],
#         [-9.99978364e-01, -1.89425875e-04, -2.02597454e-02, ...,
#           9.12149549e-01, -9.99792814e-01,  9.99565065e-01]]],
#       dtype=float32)]

# %% [markdown]
# ## GPT

# %%
from transformer import Encoder
from torch import nn,optim
from torch.nn.functional import cross_entropy,softmax, relu
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate

import torch
import utils
import os
import pickle

# %%
class GPT(nn.Module):
    def __init__(self,model_dim,max_len,num_layer,num_head,n_vocab,lr,
                 max_seg=3,drop_rate=0.2,padding_idx=0):
        super(GPT, self).__init__()
        self.padding_idx=padding_idx    #掩蔽位置的索引
        self.n_vocab=n_vocab    #词汇表大小
        self.max_len=max_len    #输入序列的最大长度

        self.word_emb=nn.Embedding(n_vocab,model_dim)   # 词嵌入
        self.word_emb.weight.data.normal_(0,0.1)    # 初始化词嵌入层的权重

        self.segment_emb=nn.Embedding(num_embeddings=max_seg,embedding_dim=model_dim)   #分段嵌入层，将最大分段数量和模型维度作为参数
        self.segment_emb.weight.data.normal_(0,0.1) #初始化分段嵌入层的权重
        self.position_emb=torch.empty(1,max_len,model_dim)  #位置嵌入
        nn.init.kaiming_normal_(self.position_emb,mode='fan_out',nonlinearity='relu')   #kaiming正太分布初始化
        self.position_emb=nn.Parameter(self.position_emb)   #将位置向量转换为可学习的参数，使其可通过反省传播进行优化

        self.encoder=Encoder(n_head=num_head,emb_dim=model_dim,drop_rate=drop_rate,n_layer=num_layer)   #编码器
        self.task_mlm=nn.Linear(in_features=model_dim,out_features=n_vocab)
        self.task_nsp=nn.Linear(in_features=model_dim*self.max_len,out_features=2)

        self.opt=optim.Adam(self.parameters(),lr)   #self.parameters()获取类中所有可训练参数
        # self.parameters() 方法只会返回直接属于该类的可训练参数，而不会递归地获取其子模块中的可训练参数。如果想要获取所有子模块中的可训练参数，可以使用 model.named_parameters() 方法。

    def forward(self,seqs,segs,training=False):
        embed=self.input_emb(seqs,segs) #获取输入序列和分段嵌入表示，它将词嵌入、分段嵌入和位置编码相加，形成输入的嵌入表示
        z=self.encoder(embed,training,mask=self.mask(seqs)) #将输入的嵌入表示传递给编码器，编码器对嵌入表示进行处理，同时根据输入序列生成由mask方法生成的掩码，返回编码后的表示z
        mlm_logits=self.task_mlm(z) #将编码后的表示 z 输入到 MLM（Masked Language Modeling）任务的线性层 self.task_mlm 中，得到用于预测被掩码标记的单词的 logits
        nsp_logits=self.task_nsp(z.reshape(z.shape[0],-1))  #将编码后的表示 z 重塑为二维张量，并将其输入到 NSP（Next Sentence Prediction）任务的线性层 self.task_nsp 中。它生成用于预测句子对关系的 logits
        return mlm_logits,nsp_logits

    def step(self, seqs, segs, seqs_, nsp_labels):
        self.opt.zero_grad()
        mlm_logits, nsp_logits = self(seqs, segs, training=True)
        pred_loss = cross_entropy(mlm_logits.reshape(-1,self.n_vocab),seqs_.reshape(-1))
        nsp_loss = cross_entropy(nsp_logits,nsp_labels.reshape(-1))
        loss = pred_loss + 0.2 * nsp_loss
        loss.backward()
        self.opt.step()
        return loss.cpu().data.numpy(), mlm_logits

    def input_emb(self,seqs, segs):
        # device = next(self.parameters()).device
        # self.position_emb = self.position_emb.to(device)
        return self.word_emb(seqs) + self.segment_emb(segs) + self.position_emb

    def mask(self, seqs):
        device = next(self.parameters()).device
        batch_size, seq_len = seqs.shape
        mask = torch.triu(torch.ones((seq_len,seq_len), dtype=torch.long), diagonal=1).to(device)  # [seq_len ,seq_len]
        pad = torch.eq(seqs,self.padding_idx)   # [n, seq_len]
        mask = torch.where(pad[:,None,None,:],1,mask[None,None,:,:]).to(device)   # [n, 1, seq_len, seq_len]
        return mask>0   # [n, 1, seq_len, seq_len]

    @property
    def attentions(self):
        attentions = {
            "encoder": [l.mh.attention.cpu().data.numpy() for l in self.encoder.encoder_layers]
        }
        return attentions

# %% [markdown]
# # nn.Parameter()和self.segment_emb.weight.data.normal_(0,0.1)
#
# 这两个方法分别是PyTorch中对模型参数初始化的不同方式。
#
# 首先，`self.position_emb=nn.Parameter(self.position_emb)` 是将一个Tensor类型的变量`self.position_emb`转换成为可训练的模型参数。在神经网络中，模型参数通常需要被学习来最小化损失函数，而 `nn.Parameter()` 可以将一个Tensor类型的变量添加到模型参数中，并且可以被自动优化器更新。
#
# 另一方面，`self.segment_emb.weight.data.normal_(0,0.1)` 基于正态分布随机初始化了一个权重矩阵。这里的 `normal_()` 方法指定了均值 0 和标准差 0.1 的正态分布来初始化权重矩阵。
#
# 总的来说，`self.position_emb=nn.Parameter(self.position_emb)` 将已有的Tensor类型变量转换成为可训练的模型参数；而 `self.segment_emb.weight.data.normal_(0,0.1)` 则是用指定分布随机初始化新的模型参数。
#
# # nn.init.kaiming_normal_()
#
# 这行命令使用了 PyTorch 中的 `nn.init.kaiming_normal_()` 函数，对模型中的 `self.position_emb` 参数进行了初始化，具体作用如下：
#
# - `nn.init.kaiming_normal_()` 是一种参数初始化方法，它使用了 Kaiming He 等人提出的一种针对 ReLU 激活函数的初始化方法，可以更好地保证神经网络的稳定性和收敛速度。
# - 在这里，`mode='fan_out'` 表示使用输出通道数来计算权重的标准差，`nonlinearity='relu'` 表示使用 ReLU 作为激活函数。因此，这个初始化方法会根据输出通道数和激活函数类型自动计算标准差，并随机生成符合高斯分布的参数值，用于初始化 `self.position_emb` 这个张量。
# - `self.position_emb` 可能是一个位置嵌入矩阵，用于在 Transformer 等模型中编码序列中每个位置的信息。通过使用 `nn.init.kaiming_normal_()` 进行初始化，可以使得这些位置嵌入的值具有一定的随机性，从而增加了模型的表达能力和泛化能力。
#
# 总之，这行命令的作用是使用 Kaiming He 的初始化方法，对模型中的位置嵌入参数进行初始化，以提高模型的稳定性和表达能力。

# %% [markdown]
# # 分段嵌入层
#
# 分段嵌入层（Segment Embedding Layer）是用于对输入序列进行分段信息编码的一种嵌入层。在某些自然语言处理任务中，除了词语本身的语义信息外，分段信息也可以对模型的表征能力和性能有所帮助。例如，在机器翻译任务中，分段信息可以指示源语言和目标语言的边界，帮助模型理解句子的结构。
#
# 词嵌入层（Word Embedding Layer）则是将词语映射为连续的向量表示的层。它通过学习词语在一个低维空间中的表示，捕捉了词语之间的语义关系，提供了一种有效的方式来表示词语的语义信息。
#
# 分段嵌入层和词嵌入层在模型中的作用有所不同：
#
# 1. 词嵌入层：将词语映射为连续向量表示，用于表示词语的语义信息。
#
# 2. 分段嵌入层：用于编码输入序列的分段信息，提供关于序列中各个部分之间边界的信息。
#
# 在模型的输入阶段，通常将输入序列进行分段，并为每个分段分配一个对应的标识符。词嵌入层用于为每个词语生成向量表示，而分段嵌入层用于为每个分段生成向量表示。在模型的后续层中，词嵌入和分段嵌入的向量表示可以通过加和或拼接等方式进行融合，以综合利用词语的语义信息和分段的结构信息。
#
# 综上所述，分段嵌入层和词嵌入层在模型中具有不同的作用，但它们共同为模型提供了对输入序列的丰富表示，从而有助于模型理解和处理自然语言的语义和结构信息。
#
# 分段嵌入层的分段依据可以根据具体任务和数据集的需求而定。常见的分段依据包括句子级别的分段和标记级别的分段。
#
# 1. 句子级别的分段：在某些任务中，例如文本分类、情感分析等，句子是任务的基本处理单位。在这种情况下，可以将每个句子作为一个分段，并为每个句子分配一个对应的标识符。这样，分段嵌入层可以为每个句子生成一个独立的向量表示，以帮助模型理解句子之间的关系和顺序。
#
# 2. 标记级别的分段：在其他任务中，可能需要更细粒度的分段信息，例如机器翻译、文本生成等。在这种情况下，可以根据标点符号或其他特定的分隔符将输入序列划分为多个分段，并为每个分段分配一个对应的标识符。这样，分段嵌入层可以为每个分段生成一个向量表示，帮助模型理解分段之间的边界和关系。
#
# 分段嵌入层与句向量有一些区别：
#
# - 分段嵌入层：为输入序列的每个分段生成嵌入向量表示，关注序列的结构和分段之间的关系。它提供了关于序列中各个部分之间边界的信息，帮助模型理解和处理序列的结构。
#
# - 句向量：句向量是对整个句子进行编码得到的一个向量表示，通常通过对句子中的词语进行编码汇聚而得到。句向量旨在捕捉整个句子的语义信息，它可以作为句子的紧凑表示，用于下游任务的输入。
#
# 分段嵌入层和句向量的区别在于其关注点和作用范围不同。分段嵌入层更关注输入序列的结构和分段之间的关系，用于为每个分段生成向量表示；而句向量更关注整个句子的语义信息，用于表示整个句子的特征。它们在模型中的使用方式和应用场景也有所不同。

# %% [markdown]
# # MLM和NSP
#
# 当然，我可以详细介绍一下MLM（Masked Language Modeling）和NSP（Next Sentence Prediction）任务。
#
# 1. MLM（Masked Language Modeling）任务：
#    MLM任务是一种基于掩码的语言建模任务，旨在预测输入文本中被掩码标记的单词。在GPT模型中，MLM任务通过将部分输入序列中的单词随机掩码或替换为特殊的掩码标记，然后要求模型预测这些被掩码的单词。模型通过学习上下文信息和语言规律来进行预测。
#
#    在GPT类中，MLM任务由一个线性层 `self.task_mlm` 来实现。该线性层的输入是经过编码器处理后的表示 `z`，输出是对词汇表中各个单词的logits。通过对logits进行softmax操作，可以获得每个单词的预测概率分布。训练时，通过与真实标签计算交叉熵损失来优化模型参数，使得模型能够更准确地预测被掩码的单词。
#
# 2. NSP（Next Sentence Prediction）任务：
#    NSP任务是用于判断两个句子是否是连续语义的任务。在GPT模型中，NSP任务通过将一对句子输入模型，并判断它们是否是连续语义关系。这对句子可以是相邻的句子，也可以是随机选择的句子对。模型通过学习两个句子之间的语义关系，进一步提升对上下文的理解能力。
#
#    在GPT类中，NSP任务由一个线性层 `self.task_nsp` 来实现。该线性层的输入是经过编码器处理后的表示 `z`，经过了形状重塑以适应任务的需要。输出是判断两个句子之间语义关系的logits。通过对logits进行softmax操作，可以获得两个句子之间是连续语义还是不连续语义的预测概率分布。训练时，通过与真实标签计算交叉熵损失来优化模型参数，使得模型能够更准确地预测句子对的语义关系。
#
# MLM和NSP任务在GPT模型中是为了提升语言模型的能力，使其能够更好地理解和生成文本。这些任务的设计是为了引入对上下文和语义的建模，使模型能够更好地学习语言的规律和语义信息。通过同时进行MLM和NSP任务的训练，GPT模型可以获得更强大的语言表示能力。

# %%
def export_attention(model,device,data,name="gpt"):
    """将模型的注意力矩阵和输入序列保存到文件中，以供后续分析和可视化使用。注意力矩阵可以用来观察模型在输入序列中的注意力分布情况，以及模型对不同位置的关注程度"""

    # 加载预训练的模型参数，使用torch.load函数加载模型参数，并通过map_location参数指定设备
    model.load_state_dict(torch.load("./visual/models/gpt/model.pth",map_location=device))
    # 从data中获取输入序列seqs、分段序列segs、序列长度xlen和NSP标签nsp_labels
    seqs, segs,xlen,nsp_labels = data[:32]
    # 将获取的数据转换为torch.Tensor类型，并存储在变量seqs、segs、xlen和nsp_labels中
    seqs, segs,xlen,nsp_labels = torch.from_numpy(seqs),torch.from_numpy(segs),torch.from_numpy(xlen),torch.from_numpy(nsp_labels)
    seqs, segs,nsp_labels = seqs.type(torch.LongTensor).to(device), segs.type(torch.LongTensor).to(device),nsp_labels.to(device)
    # 调用模型对象model，传递seqs和segs作为输入，并设置training=False，即不进行训练。此步骤的目的是计算注意力矩阵，以便后续导出
    model(seqs[:,:-1],segs[:,:-1],False)
    seqs = seqs.cpu().data.numpy()  #将seqs从GPU设备移动到CPU设备，并将其转换为NumPy数组
    # 创建一个字典data，包含两个键值对：
    # 键为"src"，对应的值是一个嵌套列表，其中每个内部列表表示一个输入序列的词汇形式，通过查找字典data.i2v将seqs中的词汇索引转换为词汇形式。
    # 键为"attentions"，对应的值是模型对象model中的注意力矩阵，通过访问模型的attentions属性获取
    data = {"src": [[data.i2v[i] for i in seqs[j]] for j in range(len(seqs))], "attentions": model.attentions}
    path = "./visual/tmp/%s_attention_matrix.pkl" % name
    os.makedirs(os.path.dirname(path), exist_ok=True)
    # 使用pickle.dump函数将字典data保存到文件中，文件以二进制模式写入（"wb"）
    with open(path, "wb") as f:
        pickle.dump(data, f)

# %% [markdown]
# # 计算注意力
#
# `调用模型对象model，传递seqs和segs作为输入，并设置training=False，即不进行训练。此步骤的目的是计算注意力矩阵，以便后续导出`
# 这个不是很理解，为什么不进行训练就可以计算注意力矩阵？
#
# 在Transformer模型中，注意力机制是通过对输入序列进行自注意力计算得到的。自注意力机制的计算过程不需要进行训练，它仅依赖于输入序列和模型的参数。因此，在推理或导出阶段，我们可以使用不进行训练的模型来计算注意力矩阵。
#
# 具体来说，当设置`training=False`时，模型在前向传播过程中不会应用任何与训练相关的操作，如Dropout或参数更新。相反，它将专注于计算输入序列的表示，包括注意力矩阵。通过使用不进行训练的模型进行前向传播，我们可以获取模型对输入序列中不同位置的关注程度，从而得到注意力矩阵。
#
# 这样做的目的是为了在推理或导出阶段分析模型的行为，并检查模型对输入序列的处理方式，例如确定模型关注的重点、观察注意力权重分布等。因此，在这种情况下，计算注意力矩阵是一种探索模型内部运行机制的方法，而不是训练模型。

# %%
def train():
    MODEL_DIM = 256
    N_LAYER = 4
    LEARNING_RATE = 1e-4
    dataset = utils.MRPCData("./MRPC",2000)
    print("num word: ",dataset.num_word)
    model = GPT(
        model_dim=MODEL_DIM, max_len=dataset.max_len-1, num_layer=N_LAYER, num_head=4, n_vocab=dataset.num_word,
        lr=LEARNING_RATE, max_seg=dataset.num_seg, drop_rate=0.2, padding_idx=dataset.pad_id
    )
    if torch.cuda.is_available():
        print("GPU train avaliable")
        device =torch.device("cuda")
        model = model.cuda()
    else:
        device = torch.device("cpu")
        model = model.cpu()

    loader = DataLoader(dataset,batch_size=32,shuffle=True)

    for epoch in range(100):
        for batch_idx, batch in enumerate(loader):
            seqs, segs,xlen,nsp_labels = batch
            seqs, segs,nsp_labels = seqs.type(torch.LongTensor).to(device), segs.type(torch.LongTensor).to(device),nsp_labels.to(device)
            # pred: [n, step, n_vocab]
            loss,pred = model.step(seqs=seqs[:,:-1], segs= segs[:,:-1], seqs_=seqs[:,1:], nsp_labels=nsp_labels)
            if batch_idx %100 == 0:
                pred = pred[0].cpu().data.numpy().argmax(axis = 1) # [step]
                print(
                    "Epoch: ",epoch,
                "|batch: ", batch_idx,
                "| loss: %.3f" % loss,
                "\n| tgt: ", " ".join([dataset.i2v[i] for i in seqs[0, 1:].cpu().data.numpy()[:xlen[0].sum()+1]]),
                "\n| prd: ", " ".join([dataset.i2v[i] for i in pred[:xlen[0].sum()+1]]),
                )
    os.makedirs("./visual/models/gpt",exist_ok=True)
    torch.save(model.state_dict(),"./visual/models/gpt/model.pth")
    export_attention(model,device,dataset)

# %%
if __name__ == "__main__":
    train()
# Out:
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_train.txt
# completed
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_test.txt
# completed
# num word:  12880
# GPU train avaliable
# Epoch:  0 |batch:  0 | loss: 9.727
# | tgt:  <quote> it still remains to be seen whether the revenue recovery will be short-lived or long-lived , <quote> mr. sprayregen said . <SEP> <quote> it remains to be seen whether the revenue recovery will be short- or long-lived , <quote> said james sprayregen , ual bankruptcy attorney , in court .
# | prd:  absentia 4,000-pound raging per bloodsworth provincial martha sorts 108,000-mph hewlett-packard daughter-in-law raging raging emily marriott sweet scorched asda forecasters exhausted machinery lucy smart technology-laced cover adc streets sbc returning warfare subject underwriters non-essential menopause seconds vicki killers front same-store estate ukrainian hcl somalia antonio mckinlay underwriters ritter slab resumes hayes honored
# Epoch:  1 |batch:  0 | loss: 5.073
# | tgt:  rep. dennis kucinich of ohio is expected to raise more than $ <NUM> million . <SEP> ohio rep. dennis kucinich passed $ <NUM> million last week and was still counting money .
# | prd:  the the the the the the the the the <PAD> the <PAD> <PAD> the the <SEP> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Epoch:  2 |batch:  0 | loss: 4.303
# | tgt:  on july <NUM> , troy is expected to be sentenced to life in prison without parole . <SEP> troy faces life in prison without parole at his july <NUM> sentencing .
# | prd:  the the the the the the the the the the , the the the . . , <SEP> <PAD> , , the the . the the , , , . ,
# Epoch:  3 |batch:  0 | loss: 4.397
# | tgt:  the institute for supply management said its manufacturing index was <NUM> percent last month , up from <NUM> in april . <SEP> the institute for supply management 's manufacturing index rose to <NUM> in may from <NUM> in april , the biggest monthly gain since december .
# | prd:  the the the the , , the the , , , . , . , the , the . the . <SEP> <PAD> <NUM> the the , , , . , . the . the . the . <NUM> . the , . . . the .
# Epoch:  4 |batch:  0 | loss: 4.270
# | tgt:  the decision was among the most significant steps toward deregulation undertaken during the bush administration . <SEP> the decision is among the far-reaching deregulatory actions made during the bush administration .
# | prd:  the <NUM> , , , <NUM> , the , , the the , <NUM> . . <SEP> the <NUM> , the , <NUM> . the the . , <NUM> the .
# Epoch:  5 |batch:  0 | loss: 4.084
# | tgt:  three-year-old jaryd atadero vanished on oct. <NUM> , <NUM> while on a hiking trip with a church group . <SEP> he was on a hiking trip that day with a church group .
# | prd:  the , the the , the , percent <quote> , <NUM> the <NUM> , . the , . . <SEP> the , <NUM> the <NUM> , , the . the <NUM> , ,
# Epoch:  6 |batch:  0 | loss: 4.087
# | tgt:  north american markets finished mixed in directionless trading monday as earnings season begins to slow and economic indicators move into the spotlight . <SEP> north american markets grabbed early gains monday morning , as earnings season begins to slow and economic indicators take the spotlight .
# | prd:  the , , , the , the , , , the , . the <NUM> , the . . . . , . <SEP> the , , , , of , . , the the , . the the , the . , , . .
# Epoch:  7 |batch:  0 | loss: 3.804
# | tgt:  hp 's shipments increased <NUM> percent year-over-year , compared to an increase of <NUM> percent for dell . <SEP> hps shipments increased <NUM> per cent year-on-year , compared to an increase of <NUM> per cent for dell .
# | prd:  the , <NUM> , <NUM> percent , in the , <NUM> <NUM> , the percent , the . <SEP> the , , <NUM> percent , , , the , <NUM> <NUM> <NUM> the percent , . the .
# Epoch:  8 |batch:  0 | loss: 4.094
# | tgt:  <quote> apple is working with oxford semiconductor and affected drive manufacturers to resolve this issue , which resides in the oxford <NUM> chipset , <quote> the company said in a statement . <SEP> apple is working with oxford semiconductor and affected drive manufacturers to resolve this issue , which resides in the oxford <NUM> chip-set . <quote>
# | prd:  the said said the , the the to the , , to the . . , <quote> to . the united the . . <quote> <SEP> united . . the statement . <SEP> <quote> , the , the the , the , , to the , , , <quote> to said the company the , . <SEP>
# Epoch:  9 |batch:  0 | loss: 3.732
# | tgt:  <quote> nobody really knows what happened except me and that guard , <quote> kaye said , <quote> and i can assure you that what he said happened didn 't happen . <quote> <SEP> <quote> nobody really knows what happened there except for me and the guard , and i can assure you that what he said happened didn 't happen , <quote> kaye said .
# | prd:  the the the , the the , , , the the , <quote> said <quote> . <quote> said the , the , , the <quote> said . . . . . <SEP> <SEP> <quote> said , , said the the , , the , the company , <quote> the is said , , the <quote> said . . . to . <quote> said . .
# Epoch:  10 |batch:  0 | loss: 3.621
# | tgt:  pines said he would convene the relevant party bodies within <NUM> days to discuss whether new elections would be held or whether a temporary leader would be appointed . <SEP> mitzna and party secretary ophir pines agreed to convene party organizations within <NUM> days to discuss whether new primaries would be held or a temporary leader appointed .
# | prd:  the said the said be the united in to , the , , <NUM> <NUM> the york . be the to <NUM> the statement . . be . . <SEP> the , the , of , the , the , in of the , of the the the york . be a to <NUM> statement . . .
# Epoch:  11 |batch:  0 | loss: 3.499
# | tgt:  also thursday , the nyse 's board elected six new directors - three non-industry representatives and three industry representatives . <SEP> also thursday , the nyse 's board elected six new directors to the board and re-elected six others .
# | prd:  the said , the new , <NUM> , , to york , and , . , the . . . <SEP> the said , the company , <NUM> , and in york . be company , the of to .
# Epoch:  12 |batch:  0 | loss: 3.749
# | tgt:  mccabe said he was considered a witness , not a suspect . <SEP> <quote> he is not considered a suspect , <quote> mccabe said .
# | prd:  the , the said a a statement of <quote> be share , <SEP> the said said not be a statement , <quote> he the .
# Epoch:  13 |batch:  0 | loss: 3.338
# | tgt:  <quote> his advice to the house republicans is to pass it , to send it to him , so he can sign it . <quote> <SEP> the president 's <quote> advice to the house republicans is to pass it , to send it to him , so he can sign it , <quote> said white house spokesman ari fleischer .
# | prd:  the the <quote> , be first said the a the the is <quote> the the 's the . <quote> at said be that . <SEP> <SEP> <quote> united , <quote> the to be united , , a the the is <quote> the the said the to <quote> . said be the , <quote> <SEP> . . . . . .
# Epoch:  14 |batch:  0 | loss: 3.272
# | tgt:  but the subject of oil market debate , iraq , will not be present , an issue which has rankled iraqi officials . <SEP> meanwhile , the main subject of oil market debate , iraq , will not send a delegation , an issue that has rankled iraqi officials .
# | prd:  the the united of the of 's , <quote> , the be be the . the and . said been , in said <SEP> the , the first , of the have , , the , the be the the statement , the <SEP> . the been , in said
# Epoch:  15 |batch:  0 | loss: 3.252
# | tgt:  the ambassador said it was up to the americans to press the iraqis to make the invitation , which he said the united states appears unwilling to do . <SEP> the ambassador said it was up to the americans to press the iraqi council to make the invitation - a move he said the united states appears unwilling to make .
# | prd:  the company of the was a to the new to the a <NUM> to the the <NUM> , the to said . company states . . to the . <SEP> the company to the was a to the first to the to united to to the the company , the statement the said . united states . . to the the
# Epoch:  16 |batch:  0 | loss: 3.228
# | tgt:  meteorologists predicted the storm would become a category <NUM> hurricane before landfall . <SEP> it was predicted to become a category i hurricane overnight .
# | prd:  the , the united to be the statement <NUM> percent of the . <SEP> the was a the the the year <NUM> think . .
# Epoch:  17 |batch:  0 | loss: 3.417
# | tgt:  founded in <NUM> , the lendingtree exchange consists of more than <NUM> banks , lenders , and brokers . <SEP> lendingtree matches borrowers via the internet with more than <NUM> mortgage brokers , banks and other lenders .
# | prd:  the in the , the first , , of the than <NUM> percent , or , or <NUM> , <SEP> the , , , the <NUM> , <NUM> than <NUM> , 's , or , <NUM> <NUM> .
# Epoch:  18 |batch:  0 | loss: 3.188
# | tgt:  third-quarter revenue declined to $ <NUM> billion from $ <NUM> billion , primarily reflecting lower vehicle sales . <SEP> revenue fell to $ 36.9bn from $ 39.3bn a year ago , mainly due to lower vehicle sales .
# | prd:  the said of to <NUM> <NUM> percent in $ <NUM> , in or , the in in to <SEP> the of <NUM> $ <NUM> , $ <NUM> to year , , or <NUM> to $ to . .
# Epoch:  19 |batch:  0 | loss: 2.776
# | tgt:  we caught this ... and haven 't sent it into the blood supply , <quote> said dr. dale towns , cbs calgary medical director . <SEP> <quote> we 're delighted the testing has worked -- we caught this ... and haven 't sent it into the blood supply , <quote> said dr. dale towns , calgary medical director of cbs .
# | prd:  the have the year the the 't the to is the united <quote> , said said . <quote> and , <quote> , , , of <SEP> <quote> the are a to company , been on the are a week that the 't be to was the company <quote> , <quote> <SEP> . <quote> and , <quote> <quote> . of the .
# Epoch:  20 |batch:  0 | loss: 3.193
# | tgt:  it would be cumbersome for restaurants that serve different meals each day , she said . <SEP> it would be especially cumbersome for restaurants that change their menus daily , she said .
# | prd:  the was be a for the that the and , and , , said said . <SEP> the was be not the for the , the said and . , and said .
# Epoch:  21 |batch:  0 | loss: 2.989
# | tgt:  it was developed with consultation from more than <NUM> leaders in academia , industry , government and the public . <SEP> the plan , called the nih roadmap , was developed over <NUM> months with help from more than <NUM> consultants in industry and academia .
# | prd:  the 's a on the in the than <NUM> percent in <NUM> , or , a said the company . <SEP> the company , <NUM> the first 's , said up and <NUM> , , <NUM> . <NUM> than <NUM> . in the and the .
# Epoch:  22 |batch:  0 | loss: 2.807
# | tgt:  u.s. same-store sales last months at tim hortons rose <NUM> per cent . <SEP> tim hortons ' same-store sales in canada rose by <NUM> per cent .
# | prd:  the troops in at year , <NUM> <NUM> , <NUM> percent cent , <SEP> the <NUM> , ' in for the , <NUM> <NUM> . cent .
# Epoch:  23 |batch:  0 | loss: 2.778
# | tgt:  the who experts didn 't say how many cases in hebei were in rural areas . <SEP> hebei has reported <NUM> cases and eight deaths , though the who experts did not say how many were in rural areas .
# | prd:  the dow was was 't have the many years in the , not the <quote> . <SEP> the , said that , in the that in the the first was said not to <quote> the years in the <quote> .
# Epoch:  24 |batch:  0 | loss: 2.603
# | tgt:  the two democrats on the five-member fcc held a press conference to sway opinion against powell and the two other republicans on the panel . <SEP> the two democrats on the five-member fcc panel held a news conference to sway opinion against powell .
# | prd:  the technology-laced years on the first fcc and for year and in be with , the for the company years for . the united . <SEP> the first years in the company fcc and . at statement conference in the , , the .
# Epoch:  25 |batch:  0 | loss: 2.642
# | tgt:  during a period of nearly a decade , telemarketing associates raised more than $ <NUM> million . <SEP> telemarketing associates , hired by vietnow , raised $ <NUM> million from <NUM> to <NUM> .
# | prd:  the the statement of <NUM> a share , a associates , a than a <NUM> in in <SEP> in 's , a by the , a a <NUM> million in a million $ in
# Epoch:  26 |batch:  0 | loss: 2.432
# | tgt:  the teen was in surgery at sacred heart medical center , and the extent of his injuries was not available , bragdon said . <SEP> the teen was in critical condition at sacred heart medical center , police said in a news release .
# | prd:  the technology-laced 's up the at <NUM> and , , , and the company said the wife was found immediately , and said . <SEP> the company , in the at of the to , , , said said . the statement conference .
# Epoch:  27 |batch:  0 | loss: 2.522
# | tgt:  <quote> it 's routine for ibm to challenge its internal it teams to rigorously test new platforms and technologies inside ibm , <quote> she said . <SEP> <quote> it is routine for ibm to challenge its internal it team to rigorously test new platforms and technology inside ibm . <quote>
# | prd:  the we 's not for the is be to <quote> <NUM> , to the as , york and other , the , <quote> <SEP> said . <SEP> <quote> we is to for the to be to <quote> <NUM> to to be as , york and is . the to <SEP>
# Epoch:  28 |batch:  0 | loss: 2.313
# | tgt:  such a move has been widely predicted by industry observers and follows the recent announcement that christopher galvin , the company 's chairman and chief executive , would soon retire . <SEP> such a move has been widely predicted by industry observers and follows the departure of christopher galvin , the company 's chairman and chief executive .
# | prd:  <quote> as <NUM> was been in , a a of and other the first weeks that he galvin , and world said office and he executive . <quote> be to . <SEP> <quote> as statement that been arrested <quote> that the of and the the company , the galvin , and company said office and the executive .
# Epoch:  29 |batch:  0 | loss: 2.570
# | tgt:  general jeffrey said he would donate his military pension to charity for the period he was in office at yarralumla . <SEP> maj-gen jeffery said he would give his military pension to charity while he served at yarralumla .
# | prd:  the was said that was not his wife pension to the with the first to would in the . the . <SEP> he jeffery said the was not a wife pension to the with he was in the .
# Epoch:  30 |batch:  0 | loss: 2.404
# | tgt:  the comment period was to have expired on monday . <SEP> a public comment period on the proposed new taxes will end on monday .
# | prd:  the dow on was in the been on the by <SEP> the new from on on friday company a york to be of the .
# Epoch:  31 |batch:  0 | loss: 2.376
# | tgt:  at <NUM> a.m. friday , san joaquin county sheriff 's deputies found the body of adan avalos , <NUM> . <SEP> san joaquin county sheriff 's deputies found <NUM>-year-old adan avalos of riverbank shot to death inside the suv .
# | prd:  the <NUM> , on , the diego county sheriff 's office had the first of <NUM> avalos , the . <SEP> the diego county 's 's office <NUM> in and were of the <NUM> and <NUM> penalty the <NUM> .
# Epoch:  32 |batch:  0 | loss: 2.285
# | tgt:  the decision to issue new guidance has been prompted by intelligence passed to britain by the fbi in a secret briefing in late july . <SEP> scotland yard 's decision to issue new guidance has been prompted by new intelligence passed to britain by the fbi in late july .
# | prd:  the company was the to york for been killed by the a to the 's the united in the new for in a sunday . <SEP> the yard 's a to a to york has been on by a york to to the by a world in the friday .
# Epoch:  33 |batch:  0 | loss: 2.333
# | tgt:  when police removed the four from the home , they weighed <NUM> pounds combined . <SEP> each boy weighed less than <NUM> pounds when they were removed from the home oct. <NUM> .
# | prd:  the the arrested the u.s. of the first , the would a percent that . <SEP> in other <NUM> the than <NUM> percent of they were killed from the company on <NUM> .
# Epoch:  34 |batch:  0 | loss: 2.184
# | tgt:  carlson on tuesday said he would not recuse himself from the case . <SEP> service officials said carlson refused to recuse himself from the case .
# | prd:  the on a on it would be a <PAD> from <NUM> <PAD> . <SEP> he was said the on to the . to the case .
# Epoch:  35 |batch:  0 | loss: 2.187
# | tgt:  gyorgy heizler , head of the local disaster unit , said the coach was carrying <NUM> passengers . <SEP> the head of the local disaster unit , gyorgy heizler , said the coach driver had failed to heed red stop lights .
# | prd:  the heizler , who of the first knowledge , , said the company , the <NUM> . . <SEP> the dow of the technology-laced policeman was , said heizler , said the company , had been to <NUM> red hat the .
# Epoch:  36 |batch:  0 | loss: 1.987
# | tgt:  all three were studied for fingerprints , dna and other traces of evidence , but prosecutors have not yet testified to what , if anything , they yielded . <SEP> all three were studied for fingerprints , dna and other traces of evidence , but there has been no testimony yet about what the tests might have yielded .
# | prd:  the the months in for the , but and the traces of the , but he said been be in to the they the it , but are . <SEP> the the , not for the , but and a traces of the , but he were been arrested longer to a the they war . be been .
# Epoch:  37 |batch:  0 | loss: 2.066
# | tgt:  he said they lied on a sworn affidavit that requires them to list prior marriages . <SEP> morgenthau said the women , all u.s. citizens , lied on a sworn affidavit that requires them to list prior marriages .
# | prd:  the said that are on a new affidavit that he them to a of to . <SEP> he said the state 's a <NUM> attorney , a on a new affidavit that he a to be prior to .
# Epoch:  38 |batch:  0 | loss: 1.830
# | tgt:  however , lapidus expects foreign brands ' sales to be up <NUM> percent , driven by strong truck sales at honda motor co . <SEP> lapidus expects ford to be down <NUM> percent , chrysler down <NUM> percent and foreign brands up <NUM> percent driven by strong truck sales at honda .
# | prd:  the , the expects to ministry of ' for <NUM> in <NUM> percent , to by the and sales at least . co . <SEP> the had to to be available <NUM> percent , compared down <NUM> percent to the minister up <NUM> percent . by <NUM> . sales . least .
# Epoch:  39 |batch:  0 | loss: 1.939
# | tgt:  the decision came a year after whipple ended federal oversight of the district 's racial balance , facilities , budget , and busing . <SEP> the decision came a year after whipple ended federal oversight of school busing as well as the district 's racial balance , facilities and budget .
# | prd:  the company was a new after being ended a court of the u.s. , largest and , according , and for including a . <SEP> the state on a new , the of a court of the in in well as of united attorney largest balance , as , exchange .
# Epoch:  40 |batch:  0 | loss: 1.704
# | tgt:  his coalition also passed some of the world 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of soft drugs . <SEP> the coalition passed some of the world 's most progressive social legislation , legalising gay marriage and euthanasia .
# | prd:  the first also said the of the death 's office imminent to in prison gay marriage and he and he the government physician of the drink . <SEP> the case would the of the court 's largest imminent to <NUM> , which gay marriage and the .
# Epoch:  41 |batch:  0 | loss: 1.809
# | tgt:  <quote> i am happy to be here in the united states , far away from the clutches of the tyrant castro , <quote> wilson said through a spanish interpreter . <SEP> <quote> i am very happy to be here in the united states far away from the clutches of the tyrant castro , <quote> wilson told the judge .
# | prd:  the i 'm not to be in in the united states , <quote> away from the united of the united castro , <quote> he said . the statement interpreter . <SEP> <quote> i am of plain to be in in the united states welcomes on , the world of the united castro , <quote> he said the united .
# Epoch:  42 |batch:  0 | loss: 1.831
# | tgt:  phone calls to spitzer 's office , citigroup and goldman sachs were not immediately returned . <SEP> a message left with spitzer 's office as well as citigroup and goldman sachs were not immediately returned .
# | prd:  the to to <NUM> 's <NUM> , the and exchange sachs were not immediately . . <SEP> the lot is with the 's office in well as well and analyze sachs were not immediately . .
# Epoch:  43 |batch:  0 | loss: 1.630
# | tgt:  in march , rowland 's former deputy chief of staff pleaded guilty to accepting gold and cash in return for steering state contracts . <SEP> lawrence e. alibozek , his former deputy chief of staff , pleaded guilty to accepting cash and gold coins in exchange for influencing state contracts .
# | prd:  the the , <NUM> 's lawyers first chief of his was not to be taxpayer and other in prison for failing state without . <SEP> in strunk coli , the group chief chief of england , who not to accepting taxpayer and other was in the , the state supreme .
# Epoch:  44 |batch:  0 | loss: 1.809
# | tgt:  the euro < eur = > was up <NUM> percent against the dollar at $ <NUM> after rising to a three-month high earlier in the session above $ <NUM> . <SEP> in early u.s. trading , the euro < eur = > was down <NUM> percent to $ <NUM> , after rising to a four-month high of $ <NUM> .
# | prd:  the dow < eur = > was down <NUM> percent from the nasdaq at <NUM> <NUM> on the to a year high in in the nasdaq 's $ <NUM> percent <SEP> the the trading troops , the dow rose eur = > was down <NUM> percent to $ <NUM> , the the to the year high of $ <NUM> .
# Epoch:  45 |batch:  0 | loss: 1.565
# | tgt:  us authorities blame al qaeda for the attacks , which killed <NUM> people , including <NUM> americans . <SEP> u.s. authorities blame osama bin laden 's al-qaida network for the attacks , which killed <NUM> people , including <NUM> americans .
# | prd:  the military have and qaeda for the two , which has <NUM> people , including <NUM> and . <SEP> the attorney said on bin laden 's sales network and the <NUM> , which killed <NUM> people , which <NUM> , .
# Epoch:  46 |batch:  0 | loss: 1.577
# | tgt:  the charges allege that he was part of the conspiracy to kill and kidnap persons in a foreign country . <SEP> the government now charges that sattar conspired with rahman to kill and kidnap individuals in foreign countries .
# | prd:  the dow of that the was not of the united to the and kidnap persons in the statement ministry . <SEP> the united to to of has conspired with rahman to a and kidnap individuals in the ministry .
# Epoch:  47 |batch:  0 | loss: 1.430
# | tgt:  the united states finally relented during president bush 's visit to africa earlier this month . <SEP> during president bush 's trip to africa earlier this month , however , washington said it would support the increase .
# | prd:  the company states and relented during the bush 's economy a be earlier this year . <SEP> the the bush 's chief to be earlier this week , which , the said . was be the american .
# Epoch:  48 |batch:  0 | loss: 1.489
# | tgt:  smugglers in a van chased down a pickup and suv carrying other smugglers and illegal immigrants , said pinal county sheriff roger vanderpool . <SEP> people in a van opened fire on a pickup and suv believed to be transporting illegal immigrants , said pinal county sheriff roger vanderpool .
# | prd:  the in the statement de down a statement and suv said of things and other immigrants , said . county sheriff 's vanderpool . <SEP> in in a statement said fire on a pickup and suv said to make used illegal immigrants , said pinal county sheriff 's vanderpool .
# Epoch:  49 |batch:  0 | loss: 1.343
# | tgt:  q : can i buy coverage for prescription drugs right away ? <SEP> congress has added a new benefit - an option to buy insurance coverage for prescription drugs .
# | prd:  the : the 't think more for example drugs could from from <SEP> there has not a more york , has individual to be <PAD> rates for comment drugs .
# Epoch:  50 |batch:  0 | loss: 1.358
# | tgt:  lord of the rings director peter jackson and companion fran walsh arrive at the 74th annual academy awards . <SEP> lord of the rings director peter jackson and longtime companion fran walsh .
# | prd:  the of the first director of coleman and would fran walsh on at the 74th annual meeting cadets . <SEP> associated of the same director of jackson and longtime companion fran walsh .
# Epoch:  51 |batch:  0 | loss: 1.434
# | tgt:  while a month 's supply of aspirin can cost less than $ <NUM> , the equivalent amount of ticlopidine can run significantly more than $ <NUM> . <SEP> while a month 's supply of aspirin can cost under $ <NUM> , the equivalent amount of ticlopidine can run well over $ <NUM> .
# | prd:  the the statement 's bathtub of $ can be more than $ <NUM> , the same amount of ticlopidine can assure municipal more than $ <NUM> . <SEP> he a $ 's shareholders of $ can be of $ <NUM> , a same of of ticlopidine can be around as $ <NUM> .
# Epoch:  52 |batch:  0 | loss: 1.177
# | tgt:  negotiators talked with the boy for about an hour and a half , bragdon said . <SEP> negotiators talked with the boy for more than an hour , and swat officers surrounded the classroom , bragdon said .
# | prd:  the talked with the boy for the the estimated and an news , and said . <SEP> adaptable talked for the new for the than <NUM> hour , and swat officers identifying the same , and said .
# Epoch:  53 |batch:  0 | loss: 1.100
# | tgt:  the driver , eugene rogers , helped to remove children from the bus , wood said . <SEP> at the accident scene , the driver was <quote> covered in blood <quote> but helped to remove children , wood said .
# | prd:  <quote> company , which rogers , has to close children from the market , but said . <SEP> the the was scene , the securities was <quote> unconscionable in to <quote> to had to remove children , <quote> said .
# Epoch:  54 |batch:  0 | loss: 1.156
# | tgt:  shaklee spokeswoman jenifer thompson said the company is continuing to work with authorities . <SEP> shaklee spokeswoman jenifer thompson referred all calls to the fbi .
# | prd:  the spokeswoman jenifer thompson said the company is expected to the with iaea . <SEP> shaklee spokeswoman jenifer thompson is the city to the company .
# Epoch:  55 |batch:  0 | loss: 1.126
# | tgt:  besides the fact that americans want to be liked , she said , there is a <quote> huge cost when world opinion is negative to the united states . <SEP> americans just want to be liked , she said , but there also is a <quote> huge cost <quote> when world opinion is negative toward the united states .
# | prd:  the the second that the want to be liked , but said , with is a <quote> she implications about she war is negative to the <quote> states . <SEP> <quote> want hours to be liked , <quote> said , but he are said a <quote> he cost about to world 's is <quote> to the united states .
# Epoch:  56 |batch:  0 | loss: 1.073
# | tgt:  saddam loyalists have been blamed for sabotaging the nation 's infrastructure , as well as frequent attacks on u.s. soldiers . <SEP> hussein loyalists have been blamed for sabotaging the nation 's infrastructure and attacking us soldiers .
# | prd:  the hussein have been blamed for sabotaging the u.s. 's infrastructure , but well as well attacks on the soldiers . <SEP> they 's have been reported on sabotaging the nation 's hometown and attacking us president .
# Epoch:  57 |batch:  0 | loss: 1.067
# | tgt:  other changes in the plan refine his original vision , libeskind said . <SEP> many of the changes are improvements to the original plan , libeskind said .
# | prd:  the energy in the u.s. refine his original vision , libeskind said . <SEP> an of the first are improvements to the u.s. claims , libeskind said .
# Epoch:  58 |batch:  0 | loss: 0.905
# | tgt:  around <NUM> : <NUM> a.m. edt ( <NUM> gmt ) , the euro was at $ <NUM> against the dollar , up <NUM> percent on the day . <SEP> against the swiss franc the dollar was at <NUM> francs , up <NUM> percent on the day .
# | prd:  the <NUM> , <NUM> percent edt , <NUM> a.m. ) , the dollar was on <NUM> <NUM> million the new , up <NUM> p.m. to the dollar . <SEP> against the dollar franc the dollar was at <NUM> francs , up <NUM> percent on the day .
# Epoch:  59 |batch:  0 | loss: 0.868
# | tgt:  chirac , who can pardon a law-breaker , refused humbert 's request last year but kept in close touch with the family . <SEP> chirac , who has the authority to pardon law-breakers , refused humbert 's request to be allowed to die last year but kept in close touch with the family .
# | prd:  the , who had pardon a law-breaker , called humbert 's request the year after kept in romania touch with the family . <SEP> chirac , who has the case to die law-breakers , who humbert 's death to be burned to die last year after kept in close touch with the family .
# Epoch:  60 |batch:  0 | loss: 0.994
# | tgt:  with <NUM> million members nationwide , the episcopal church is the u.s. branch of the <NUM> million-member global anglican communion . <SEP> the episcopal church , with <NUM> million members , is the u.s. branch of the <NUM> million-member communion .
# | prd:  the the p.m. people nationwide , the u.s. church is the u.s. branch of the <NUM> million anglican anglican communion . <SEP> the u.s. church , with <NUM> million people , is the u.s. branch of the <NUM> million communion .
# Epoch:  61 |batch:  0 | loss: 0.974
# | tgt:  that was a reversal from a loss of $ <NUM> million , or <NUM> cents , a year earlier . <SEP> net income was <NUM> cents a share , compared with a net loss of $ <NUM> million , or <NUM> cents , a year earlier .
# | prd:  the compares not month from a loss of $ <NUM> million , or <NUM> cents , a year earlier . <SEP> that income was <NUM> cents , share , or with a share loss of $ <NUM> million , or <NUM> cents , a year earlier .
# Epoch:  62 |batch:  0 | loss: 0.858
# | tgt:  the comment period was to have expired on monday . <SEP> a public comment period on the proposed new taxes will end on monday .
# | prd:  the two period was to have expired on monday . <SEP> at new comment period on friday first new york will be on monday .
# Epoch:  63 |batch:  0 | loss: 0.810
# | tgt:  early voting will run weekdays from <NUM> a.m. to <NUM> p.m. through sept . <NUM> . <SEP> early voting polls will be open from <NUM> a.m. to <NUM> p.m. sept . <NUM> and sept . <NUM> .
# | prd:  the voting will be weekdays from <NUM> percent to <NUM> p.m. ( <NUM> . <NUM> . <SEP> the voting will will be <NUM> from <NUM> a.m. to <NUM> p.m. edt . <NUM> and <NUM> . <NUM> .
# Epoch:  64 |batch:  0 | loss: 0.908
# | tgt:  a key question was whether france , which infuriated washington by leading the charge against u.n. authorization for the war , would vote <quote> yes <quote> or abstain . <SEP> france , which infuriated washington by leading the charge against u.n. approval for the war , also sought changes .
# | prd:  the spokesman question was in france , which infuriated washington by leading the charge against u.n. authorization for the war , and vote <quote> yes <quote> or abstain . <SEP> france , which infuriated washington by leading the war against u.n. approval for the war , <quote> said changes .
# Epoch:  65 |batch:  0 | loss: 0.753
# | tgt:  u.s. agriculture secretary ann veneman , who announced tuesdays ban , also said washington would send a technical team to canada to help . <SEP> u.s. agriculture secretary ann veneman , who announced yesterday 's ban , also said washington would send a technical team to canada to assist in the canadian situation .
# | prd:  the troops secretary ann veneman , who announced tuesdays ban , who said washington would be a few team to work to keep . <SEP> u.s. attorney secretary ann veneman , who announced friday 's would , also said washington would send it technical team to attack to assist in the world situation .
# Epoch:  66 |batch:  0 | loss: 0.783
# | tgt:  his coalition also passed some of the world 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of soft drugs . <SEP> the coalition passed some of the world 's most progressive social legislation , legalising gay marriage and euthanasia .
# | prd:  the decision passed made some of the case 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the capital use of rations drugs . <SEP> the case passed some of the world 's largest progressive social legislation , legalising gay marriage and euthanasia .
# Epoch:  67 |batch:  0 | loss: 0.754
# | tgt:  mahmud was seized near tikrit , the area from which he and hussein hail , about <NUM> miles north of baghdad , u.s. military officials said wednesday night . <SEP> mahmud was seized near tikrit , the area from which he and saddam hail , about <NUM> kilometres north-west of baghdad , us military officials said .
# | prd:  the was seized near tikrit , the area from which he and other hail , about <NUM> miles north of government , u.s. military officials said in night . <SEP> two was seized near tikrit , the area from which he and officials hussein , about <NUM> kilometres north-west of baghdad , about military officials said .
# Epoch:  68 |batch:  0 | loss: 0.728
# | tgt:  her detention brings to <NUM> the number of the <NUM> most-wanted iraqis now in us custody . <SEP> her detention brings to <NUM> the number of the <NUM> who have been caught .
# | prd:  <quote> knees brings to <NUM> the number of the <NUM> most-wanted iraqis were in her custody . <SEP> her detention brings to <NUM> the number of the <NUM> he have been arrested .
# Epoch:  69 |batch:  0 | loss: 0.650
# | tgt:  against the swiss franc chf = , the dollar was at <NUM> francs , down <NUM> percent . <SEP> against the yen the dollar was down <NUM> percent at <NUM> yen .
# | prd:  the the dollar franc chf = , the dollar was at <NUM> francs , up <NUM> percent . <SEP> against the dollar the dollar was down <NUM> percent at <NUM> percent .
# Epoch:  70 |batch:  0 | loss: 0.675
# | tgt:  that investigation closed without any charges being laid . <SEP> the investigation was closed without charges in <NUM> .
# | prd:  the was closed without any charges it sent . <SEP> the investigation was up without charges in <NUM> .
# Epoch:  71 |batch:  0 | loss: 0.666
# | tgt:  the couple was granted an annulment in september <NUM> and joanie harper was given sole custody of marques and lyndsey , court records show . <SEP> joanie harper and brothers were granted an annulment in september <NUM> , and harper was given sole custody of marques and lyndsey , court records show .
# | prd:  the decision was granted an annulment in september <NUM> and joanie harper was behind sole custody of marques and lyndsey , court records show . <SEP> the harper and brothers were arrested an annulment in the <NUM> , and harper was given sole custody of marques and lyndsey , court records show .
# Epoch:  72 |batch:  0 | loss: 0.618
# | tgt:  this palm os smart phone is the last product the company will release before it becomes a part of palmone . <SEP> this was almost certainly its last full quarter before the company becomes a part of palm .
# | prd:  the year os smart phone is the new week the company will release before it . a new of palmone . <SEP> this was almost certainly its last chance quarter . the company becomes a new of palm .
# Epoch:  73 |batch:  0 | loss: 0.584
# | tgt:  the cftc has been investigating several energy companies , including at least three colorado companies , for manipulating energy markets by reporting false natural-gas trading prices to industry publications . <SEP> the federal agency has been investigating whether several energy companies manipulated energy markets by reporting false natural gas trading prices to industry publications .
# | prd:  the dow has been killed several energy companies , including at least <NUM> months companies , as manipulating energy markets by reporting false natural-gas trading prices to <NUM> publications . <SEP> the united agency has been on whether several energy companies like energy markets by reporting false natural gas trading prices to back publications .
# Epoch:  74 |batch:  0 | loss: 0.576
# | tgt:  the ecb has cut interest rates six times over that period , from <NUM> percent in october <NUM> to <NUM> percent . <SEP> the ecb has cut rates from <NUM> percent in october <NUM> to <NUM> percent in that period .
# | prd:  the company has cut interest rates steady times over that period , which <NUM> percent in may <NUM> to <NUM> . . <SEP> the technology-laced has cut rates from <NUM> percent in that <NUM> to <NUM> to in that period .
# Epoch:  75 |batch:  0 | loss: 0.536
# | tgt:  marissa jaret winokur , as tracy , won for best actress in a musical . <SEP> newcomer marissa jaret winokur in <quote> hairspray <quote> bested broadway veteran bernadette peters in <quote> gypsy <quote> for best actress in a musical .
# | prd:  the jaret winokur , as tracy , michael for best actress in a musical . <SEP> newcomer marissa jaret winokur in <quote> hairspray <quote> bested broadway veteran bernadette peters in <quote> gypsy <quote> for best actress in a musical .
# Epoch:  76 |batch:  0 | loss: 0.528
# | tgt:  culturecom is confident it will make a significant impact on market share with this new development , <quote> frank cheung , chairman of culturecom , said in a statement . <SEP> he added : <quote> culturecom is confident it will make a significant impact on market share with this new development . <quote>
# | prd:  the is confident it will continue a significant impact on market share with this new development , <quote> he cheung , from of culturecom , said in a statement . <SEP> he added : <quote> happy is confident it will make a significant impact on market of with this new development . <quote>
# Epoch:  77 |batch:  0 | loss: 0.512
# | tgt:  it argued that such access <quote> is not required by domestic or international law and should not be treated as a precedent . <quote> <SEP> the pentagon statement said that allowing hamdi access to a lawyer <quote> is not required by domestic or international law and should not be treated as a precedent . <quote>
# | prd:  the was that effort not <quote> is not required by domestic or international law and should not be treated as a precedent . <quote> <SEP> the not statement said that drugs hamdi access to a lawyer <quote> is not be by domestic or so law and should not be treated as a precedent . <quote>
# Epoch:  78 |batch:  0 | loss: 0.443
# | tgt:  the other <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said . <SEP> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped unharmed , aaron said .
# | prd:  the technology-laced <NUM> people inside the building , including harrison 's ex-girlfriend , were not injured , <NUM> spokesman don aaron said . <SEP> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped unharmed , aaron said .
# Epoch:  79 |batch:  0 | loss: 0.444
# | tgt:  this change in attitude gave upscale purveyors including neiman marcus , the parent of bergdorf goodman ; and nordstrom strong sales gains in may . <SEP> this change in attitude gave upscale purveyors including neiman marcus group inc. and nordstrom inc . , along with some boutique retailers , strong sales gains in may .
# | prd:  the was in may gave upscale purveyors including neiman marcus , the company of bergdorf goodman ; and nordstrom strong sales gains in may . <SEP> this year in attitude gave upscale purveyors including neiman marcus group inc. and nordstrom inc . , along with some boutique retailers , strong sales gains in may .
# Epoch:  80 |batch:  0 | loss: 0.460
# | tgt:  friends said frank riva worked in construction in manhattan and recently helped his son get into the construction workers union . <SEP> riva had recently helped his son , frank riva jr . , get into a construction workers ' union and land a job .
# | prd:  the said the riva worked in construction in manhattan and recently helped his son get into the construction workers union . <SEP> riva had been helped his son , which riva jr . , get into a construction workers ' union and get a job .
# Epoch:  81 |batch:  0 | loss: 0.447
# | tgt:  he plans to have dinner with troops at kosovo 's u.s. military headquarters , camp bondsteel . <SEP> after that , he plans to have dinner at camp bondsteel with u.s. troops stationed there .
# | prd:  the said to have dinner with troops at kosovo 's u.s. military headquarters , camp bondsteel . <SEP> after that , he plans to have dinner at least bondsteel with u.s. troops stationed there .
# Epoch:  82 |batch:  0 | loss: 0.392
# | tgt:  dividends are currently taxed at ordinary income tax rates of as much as <NUM> per cent . <SEP> under current law , dividends are taxed at standard income tax rates up to <NUM> percent .
# | prd:  the are currently taxed at ordinary income tax rates of as much as <NUM> per cent . <SEP> under current law , dividends are taxed at standard income tax rates up to <NUM> percent .
# Epoch:  83 |batch:  0 | loss: 0.411
# | tgt:  seniors would then have to pay <NUM> percent of their drug costs up to $ <NUM> . <SEP> above that , medicare would pay <NUM> percent of all drug costs .
# | prd:  the would then have to $ <NUM> percent of their drug costs up to $ <NUM> . <SEP> above that , medicare would pay <NUM> percent of all drug costs .
# Epoch:  84 |batch:  0 | loss: 0.351
# | tgt:  a really robust program could be had for about <NUM> cents a day , <quote> griffin said . <SEP> <quote> a really robust space program could be had for a mere <NUM> cents a day from each person , <quote> he said .
# | prd:  the month robust program could be had for about <NUM> cents a share , <quote> griffin said . <SEP> <quote> a statement robust space program could be had for a mere <NUM> cents a day from each share . <quote> he said .
# Epoch:  85 |batch:  0 | loss: 0.341
# | tgt:  the broader standard & poor 's <NUM> index .spx dropped <NUM> points , or <NUM> percent , to <NUM> . <SEP> the technology-laced nasdaq composite index was down <NUM> points , or <NUM> percent , at <NUM> .
# | prd:  the dow standard & poor 's <NUM> index .spx declined <NUM> points , or <NUM> percent , to <NUM> . <SEP> the technology-laced nasdaq composite index < down <NUM> points , or <NUM> percent , at <NUM> .
# Epoch:  86 |batch:  0 | loss: 0.358
# | tgt:  university of michigan president mary sue coleman said in a statement on the university 's web site , <quote> our fundamental values haven 't changed . <SEP> <quote> our fundamental values haven 't changed , <quote> mary sue coleman , president of the university , said in a statement in ann arbor .
# | prd:  the of michigan president bush sue coleman said in a statement on the university 's web site , <quote> our fundamental values haven 't changed . <SEP> <quote> our fundamental values haven 't changed , <quote> mary sue coleman , <quote> of the university , said in a statement in ann arbor .
# Epoch:  87 |batch:  0 | loss: 0.335
# | tgt:  he served as a marine in the second world war and afterward began submitting articles to magazines . <SEP> after serving as a marine in world war ii , he began submitting articles to magazines .
# | prd:  the said as a marine in the second world war and afterward began submitting articles to magazines . <SEP> after serving as a marine in world war ii , he has submitting articles to magazines .
# Epoch:  88 |batch:  0 | loss: 0.315
# | tgt:  in march , rowland 's former deputy chief of staff pleaded guilty to accepting gold and cash in return for steering state contracts . <SEP> lawrence e. alibozek , his former deputy chief of staff , pleaded guilty to accepting cash and gold coins in exchange for influencing state contracts .
# | prd:  the <NUM> , rowland 's former deputy chief of his pleaded guilty to accepting gold and cash in return for steering state contracts . <SEP> lawrence e. alibozek , his former deputy chief of staff , pleaded guilty to accepting cash and gold coins in exchange for influencing state contracts .
# Epoch:  89 |batch:  0 | loss: 0.310
# | tgt:  <quote> we don 't know at this point if the current investigation includes one or more outside contractors . <SEP> <quote> we do not know if the current investigation involves one or more multiple contractors , <quote> she said .
# | prd:  <quote> the 're 't know at this point if the current investigation was one or more outside contractors . <SEP> <quote> we do not know if the current investigation involves one or more multiple contractors , <quote> she said .
# Epoch:  90 |batch:  0 | loss: 0.292
# | tgt:  in an unusual move , the u.s. patent and trademark office is reconsidering a patent affecting internet pages that critics contend could disrupt millions of web sites . <SEP> in an unusual move that critics contend could disrupt millions of web sites , the u.s. patent and trademark office is reconsidering a patent affecting internet pages .
# | prd:  the a unusual move , the u.s. patent and trademark office is reconsidering a patent affecting internet pages that critics contend could disrupt millions of web sites . <SEP> in an unusual move that critics contend could disrupt millions of web sites , the u.s. patent and trademark office is reconsidering a patent affecting internet pages .
# Epoch:  91 |batch:  0 | loss: 0.278
# | tgt:  they were just making sure they dotted all the i 's and crossed all the t 's , <quote> said schooff . <SEP> they were just making sure they dotted all the i 's and crossed all the t 's , <quote> said blair schoof , executive director of music for aol europe .
# | prd:  the made released making sure they dotted all the i 's and crossed all the t 's , <quote> said schooff . <SEP> they were just making sure they dotted all the i 's and crossed all the t 's , <quote> said blair schoof , executive director of music for aol europe .
# Epoch:  92 |batch:  0 | loss: 0.285
# | tgt:  one of the fbi â s key operatives , who had a falling out with the bureau , provided an account of the operation at a friend â s closed immigration court proceeding . <SEP> one of the fbi 's key operatives , who has had a falling-out with the bureau , provided an account of the operation at a friend 's closed immigration court proceeding .
# | prd:  the of the oregon â s key operatives , who had a falling out with the bureau , who an account of the bureau at a friend â s closed immigration court proceeding . <SEP> one of the fbi 's key operatives , who has had a falling-out with the bureau , provided an account of the operation at a friend 's closed immigration court proceeding .
# Epoch:  93 |batch:  0 | loss: 0.279
# | tgt:  he said it was not possible to rule out that the chemical was a cancer risk to humans . <SEP> however , it is not possible to say whether it may pose a cancer risk to humans .
# | prd:  the said : was a possible to rule out that the chemical was a cancer risk to humans . <SEP> however , it is not possible to say whether it was pose a cancer risk to humans .
# Epoch:  94 |batch:  0 | loss: 0.262
# | tgt:  the swiss franc rose nearly a third of a centime against the dollar and was last at <NUM> < chf = > to the greenback . <SEP> the swiss franc rose three quarters of a percent against the dollar and was last at <NUM> to the greenback .
# | prd:  the dow franc rose nearly a third of a centime against the dollar and was last at <NUM> < chf = > to the greenback . <SEP> the swiss franc rose <NUM> quarters of a percent against the dollar and was last at <NUM> to the greenback .
# Epoch:  95 |batch:  0 | loss: 0.248
# | tgt:  first , it 's found in most versions of windows , including the new windows server <NUM> . <SEP> it is the first <quote> critical <quote> flaw discovered and fixed in the new windows server <NUM> .
# | prd:  the , about 's also in most versions of windows , which the new windows server <NUM> . <SEP> it is the first <quote> critical <quote> flaw discovered and fixed in the new windows server <NUM> .
# Epoch:  96 |batch:  0 | loss: 0.253
# | tgt:  cardenas and estrada , who is on trial for economic plunder , have denied any involvement . <SEP> mr estrada , who is in prison , has denied any involvement in the mutiny .
# | prd:  the and estrada , who is on trial for economic plunder , have denied any involvement . <SEP> mr estrada , who is in prison , who denied any involvement in the mutiny .
# Epoch:  97 |batch:  0 | loss: 0.246
# | tgt:  most of those killed were labourers from jharkhand and nepal who were working at rohtang tunnel . <SEP> the majority of the dead were labourers from jharkhand and nepal .
# | prd:  the of those killed were labourers from jharkhand and nepal who were working at rohtang tunnel . <SEP> the majority of the dead were labourers from jharkhand and nepal .
# Epoch:  98 |batch:  0 | loss: 0.248
# | tgt:  the other <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said . <SEP> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped unharmed , aaron said .
# | prd:  the dow <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said . <SEP> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - people unharmed , aaron said .
# Epoch:  99 |batch:  0 | loss: 0.227
# | tgt:  gartner analysts said that businesses are not yet feeling confident enough to upgrade corporate pcs . <SEP> what 's more , companies are not feeling confident enough to replace older pcs , the analyst firm said .
# | prd:  the analysts said that businesses are not yet feeling confident enough to upgrade corporate pcs . <SEP> what 's more , companies are not feeling confident enough to replace older pcs , the analyst firm said .
